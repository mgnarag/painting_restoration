# %% [markdown]
# <a href="https://colab.research.google.com/github/mgnarag/painting_restoration/blob/main/unet_RGB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !ls drive/My\ Drive
file_path = "/content/drive/MyDrive/Baumgartner screenshots/"
# Out:
# '107.1 syllabus 1SAY1920 FINAL.gdoc'
# '1C-01 Narag et al (1).pdf'
# '1C-01 Narag et al.pdf'
# '1FA971504AC646559D05A8ED6341AFB3[1025340].png'
# '1H-04 Narag et al.pdf'
#  20220802_182749.heic
#  20220802_182831.heic
#  20220802_183259.heic
#  20220803_125819.heic
#  20220803_125842.heic
#  20220803_144229.heic
#  20220803_144422.heic
#  20220803_160724.heic
#  20220803_160751.heic
#  20220803_165240.heic
#  20220803_165318.heic
#  20220803_174701.heic
#  20220803_174706.heic
#  20220804_175217.heic
#  20220804_175443.heic
#  20220804_175616.heic
#  20220804_181917.heic
#  20220804_182007.heic
#  20220804_182117.heic
#  2S22-23_LE3-Regular-Set-A-FINAL-KEY.pdf
# '3 classes (polarized)CM_alexnet.png'
# '3 classes (polarized)CM_vgg.png'
# 'A4_Physics 71 TWHFU-3_gradesheet (1).pdf'
# 'A4_Physics 71 TWHFU-3_officialgrades (1).pdf'
# 'A4_Physics 71 TWHFU-3_officialgrades.gdoc'
# 'Abstract - NARAG, Mark Jeremy.pdf'
# 'Annex 1 (copy of Journal).pdf'
# 'Annex 2 (Proof of employments).pdf'
# 'App Physics 181 THY-FX-2_studentcontactlist.xlsx'
#  Architectural_designs
# 'Arki abstract.pdf'
# 'Arki full paper.pdf'
# '[ART] Example of Objectives - Activities - Exp Output OPTIKAL WBS version 2.gsheet'
#  autoencoder_fine_tuned_6
# 'autoencoder_fine_tuned_6 (1)'
#  autoencoder_fine_tuned_6_b
# 'Baumgartner screenshots'
# 'Binarizing architectural drawings'
#  classification_report_nonTL.xlsx
#  classification_report.xlsx
#  Classroom
# 'CLEAN32_AB_INPUT_[09] Preserve and Protect.png'
# 'CLEAN32_AB_TEST_INPUT_[04] Coming into Bloom_V1.png'
# 'CLEAN32LAB_Copy of [05] Comprimise-d - Before.png'
# 'CLEAN_TEST_INPUT_[04] Coming into Bloom.png'
# 'Colab Notebooks'
# 'Color Difference Specification 2016.pptx'
#  confusion_matrix_nonTL.png
#  confusion_matrix_nonTL.xlsx
#  CS284
#  CS_NIP_201819_S2_BS_AppliedPhysics_Narag_Mark_Jeremy.pdf
#  D54dUVpU8AIZzoD.jpeg
#  Data.tex
# 'Dormitory Stay Request MNarag.docx.pdf'
# '[DRAFT-ART] UP Intelligent Systems Center Research Grant Application - Preview.docx'
#  DrzPc0sUwAAyQHi.jpeg
#  DvO96koV4AAD6PP.jpeg
# 'DvO976tVAAEQ9ym (1).jpeg'
#  DvO976tVAAEQ9ym.jpeg
# 'Employment Survey.gdoc'
#  Fast-Dreambooth
# 'FBC-2_Banez (1).pdf'
#  FBC-2_Banez.pdf
#  FdUaD2nUcAAki1b.jpeg
# 'Figure 1.png'
# 'Figure 2.png'
# 'fingerprint (1).pb'
# 'fingerprint (2).pb'
# 'fingerprint (3).pb'
# 'fingerprint (4).pb'
# 'fingerprint (5).pb'
#  fingerprint.pb
# 'Form5a and Grades.zip'
#  Fringes.zip
#  FSR_120201_NARAG_MARK_JEREMY_GACIAS_NIP.pdf
#  FSR_120202_NARAG_MARK_JEREMY_GACIAS_NIP.pdf
#  FSR_120212_NARAG_MARK_JEREMY_GACIAS_NIP.pdf
#  FSR_120221_NARAG_MARK_JEREMY_GACIAS_NIP.pdf
# 'Geology (Ate Grass)'
# 'Geology (Ate Grass) (1)'
# 'Getting started.pdf'
#  IMG_4258.HEIC
#  IMG_4259.HEIC
#  IMG_4260.HEIC
#  IMG_4261.HEIC
#  IMG_4262.HEIC
#  IMG_4263.HEIC
#  IMG_4288.HEIC
#  IMG_5634.JPG
#  IMG_6572.jpeg
#  IMG_6578.jpeg
# 'IMG_6587 (1).jpeg'
#  IMG_6587.jpeg
#  IPA-Form4.1-2021Rev072021-1.pdf
#  IPA-Form4.2-2021Rev072021.docx
#  IPA-Form4.3-2021Rev072021.pdf
# 'item sample.tex'
# 'item template.tex'
# 'Jas Jem utang.gsheet'
#  Jem_face
# 'JFR Reduced Fees for 1st Sem AY 20-21.zip'
# 'Lecture 22 - Torque.pptx'
# 'Lecture 23 - Dynamics of Rotation.pptx'
# 'Lecture 24 - Angular Momentum.pptx'
# 'Lecture 25 - Equilibrium and Center of Gravity.pptx'
# 'Lecture 26 - Density and Pressure in a Fluid.pptx'
# 'Lecture 27 - Buoyancy.pptx'
# 'LRM_20220804_195432 (1).dng'
#  LRM_20220804_195432.dng
#  LRM_20220804_195500.dng
#  LRM_20220804_195546.dng
#  LRM_20220805_113837.dng
#  LRM_20220805_142837.dng
#  LRM_20220805_143054.dng
#  LRM_20220805_143817.dng
# 'MALIPOL_CHAE ANN.pdf'
#  Metric_100dpi.csv
#  Metric_500.csv
# 'NARAG_MARKJEREMY (1).BC.pdf'
#  NARAG_MARKJEREMY.BC.pdf
#  NARAG_MARKJEREMY.CC.png
#  NARAG_MARKJEREMY.dcog.pdf
#  NARAG_MARKJEREMY.DC.pdf
#  NARAG_MARKJEREMY.FL.pdf
#  NARAG_MARKJEREMY.Form1.1.pdf
#  NARAG_MARKJEREMY.POS.pdf
#  NARAG_MARKJEREMY.SD.pdf
#  NARAG_MARKJEREMY.TCGTOR.pdf
# '[NARAG] Physics 242 Final Report.pdf'
# '[NARAG] Physics 242 PS 1.pdf'
# '[NARAG] Physics 242 PS 2.pdf'
# 'Narag SPP Cert.pdf'
#  NARAG_Travel-Report-Form-2019.pdf
# 'NIP COVID-19 Case Report Form.gform'
# 'NIP COVID-19 Case Report Form (Responses).gsheet'
# 'NIP COVID19 Report.gsheet'
# 'NIP Year End Party 2022'
#  NRAG_MARKJEREMY.OTRTCG.pdf
# 'Optics in Art and Art Analysis (1).pptx'
# 'Optics in Art and Art Analysis.pptx'
# 'OUR CErtificate.gdoc'
# 'OUR CErtificate.pdf'
# 'output v1_100dpi.png'
# 'output v2_100dpi.png'
# 'output v3_100dpi.png'
# 'output v3_500.png'
# 'output v4_100dpi.png'
# 'output v5_100dpi.png'
# 'output v6_100dpi.png'
# 'OVCRD IPA Reference Slip (2021-0929-1691-5873).pdf'
# 'PA-08 Narag et al.pdf'
#  PA-08.pdf
# 'Parallel Presentation.gslides'
# 'PEER EVALUTION - Physics 72.1 HBC-1 .gform'
# 'PEER EVALUTION - Physics 72.1 TDE-1 .gform'
# 'PEER EVALUTION - Physics 72.1 WDE-1 .gform'
# 'PhD Candidacy Slides.pdf'
# 'PhD Candidacy Slides.pptx'
# 'Physics 107.1 Drive'
# 'Physics 107.1 MBCD-2_studentcontactlist.xlsx'
#  Physics305_plasma
# 'Physics 71.1 WIJ FIJ and 72.1 TBC.gsheet'
#  Physics_71_Syllabus.zip
# 'Physics_71_Syllabus.zip (Unzipped Files)'
# '[Physics 71 V-2] Attendance.gsheet'
# 'Physics 72.1 2nd Sem AY 2019-2020.gsheet'
# 'Rene Jem utang.gsheet'
# 'Research files'
# 'Sablay picture.jpeg'
# 'saved_model (1).pb'
# 'saved_model (2).pb'
# 'saved_model (3).pb'
# 'saved_model (4).pb'
# 'saved_model (5).pb'
#  saved_model.pb
# 'Screenshot 2023-02-12 at 12.13.51 (1).png'
# 'Screenshot 2023-02-12 at 12.13.51.png'
# 'Screenshot 2023-06-29 at 19.20.04.png'
# 'Screenshot 2023-06-29 at 19.26.09.png'
#  sd
#  Smokers.mp4
# 'SORRY SIR HUHU.gdoc'
# 'SORRY SIR HUHU.pdf'
# 'SPP-2023-1H-04 (1).pptx'
#  SPP-2023-1H-04.pptx
#  SPP_2023-Contributed-26.pdf
# 'SPP-2023-PB-05  .pdf'
#  SPP_Appearance-45.pdf
# 'SPP Cert of Appearance NARAG (1).pdf'
# 'SPP Cert of Appearance NARAG (2).pdf'
# 'SPP Cert of Appearance NARAG.pdf'
# 'Testing on DIV2K dataset.pdf'
# '[THY-FX] Physics 181 LE1 Submissions 2nd Sem AY 2020-21'
#  Travel-Report-Form-2019.pdf
# 'Undergraduate Research'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet.gsheet'
# '[Updated] Physics 71 THQ-FQ-1_studentcontactlist (1).xlsx'
# '[Updated] Physics 71 THQ-FQ-1_studentcontactlist.xlsx'
# 'variables (1).data-00000-of-00001'
# 'variables (2).data-00000-of-00001'
# 'variables (3).data-00000-of-00001'
# 'variables (4).data-00000-of-00001'
# 'variables (5).data-00000-of-00001'
#  variables.data-00000-of-00001
# 'Waiver for more than 18 units [2nd sem AY 20-21].gdoc'

# %% [markdown]
# ## Installing packages

# %%
import time
import pandas as pd

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

from PIL import Image, ImageOps
import os
import numpy as np

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from scipy.ndimage import zoom

import cv2
from skimage import color

from tensorflow import keras
from PIL import Image, ImageOps
import numpy as np
import PIL
PIL.Image.MAX_IMAGE_PIXELS = 236958876
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Defining functions

# %%
def zoom_and_resize(img, zoom_factor):
    height, width = img.shape[:2]
    crop_top = int((height - height / zoom_factor) / 2)# Calculate the region to crop around the center
    crop_bottom = int(height - crop_top)
    crop_left = int((width - width / zoom_factor) / 2)
    crop_right = int(width - crop_left)
    cropped_image = img[crop_top:crop_bottom, crop_left:crop_right]    # Crop the image
    resized_image = cv2.resize(cropped_image, (width, height))# Resize the zoomed image back to the original dimensions
    return resized_image

def crop(im):
    width, height = im.size
    data = []
    step = int(size * 0.80)  # Adjust the step size for cropping
    for j in range(0, height, step):
        for i in range(0, width, step):
            if i + size <= width and j + size <= height:
                im1 = im.crop((i, j, i + size, j + size))
                im1 = np.array(im1).astype(np.float32)
                data.append(im1/255)
                #im1 = np.rot90(im1)
                #data.append(im1/255)
                #im1 = np.rot90(im1)
                #data.append(im1/255)
                #im1 = np.rot90(im1)
                #data.append(im1/255)
                for z in zoom_factor:
                    zoomed_img = zoom_and_resize(im1, z)
                    data.append(zoomed_img/255)
    return data

def contrast_stretch(image):
    img_array = np.array(image)
    for i in range(3):  # 3 channels: Red, Green, Blue
        # Compute min and max pixel intensity values for the channel
        min_val = np.min(img_array[:,:,i])
        max_val = np.max(img_array[:,:,i])
        # Apply contrast stretching
        img_array[:,:,i] = (img_array[:,:,i] - min_val) * (255.0 / (max_val - min_val))
    # Convert numpy array back to PIL Image
    stretched_image = Image.fromarray(np.uint8(img_array))
    return stretched_image

# %% [markdown]
# ## Preparing the training dataset

# %%
size = 32
model_number = size

zoom_factor = [1.50, 2.0]
input = []
output = []

input_folder_path = file_path + 'Training/input/'
output_folder_path = file_path + 'Training/output/'

# List all files in the directory and sort them alphabetically
input_files = sorted(os.listdir(input_folder_path))
output_files = sorted(os.listdir(output_folder_path))


for image_file in input_files:
    image_path = os.path.join(input_folder_path, image_file)
    image = contrast_stretch(Image.open(image_path).convert('RGB'))
    image = crop(image)
    input.extend(image)

for image_file in output_files:
    image_path = os.path.join(output_folder_path, image_file)
    image = Image.open(image_path).convert('RGB')
    image = crop(image)
    output.extend(image)
input = np.array(input)
output = np.array(output)

print("Done reading the input of size = ", input.shape)
print("Done reading the output of size = ", output.shape)

# Split the data into training and testing sets
train_input, test_input, train_output, test_output = train_test_split(
    input, output, test_size=0.2, random_state=42)

print("Done reading the train input of size = ", train_input.shape)
print("Done reading the test input of size = ", test_input.shape)
print("Done reading the train output of size = ", train_input.shape)
print("Done reading the test output of size = ", test_input.shape)

input = []
output = []
# Out:
# Done reading the input of size =  (23874, 32, 32, 3)
# Done reading the output of size =  (23874, 32, 32, 3)
# Done reading the train input of size =  (19099, 32, 32, 3)
# Done reading the test input of size =  (4775, 32, 32, 3)
# Done reading the train output of size =  (19099, 32, 32, 3)
# Done reading the test output of size =  (4775, 32, 32, 3)

# %%
N = 15000
n = 10
plt.figure(figsize=(20, 4))
for i in range(0,10):
    ax = plt.subplot(2, n, i + 1)
    plt.title("input")
    plt.imshow((train_input[i+N]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    bx = plt.subplot(2, n, i + n + 1)
    plt.title("output")
    plt.imshow((train_output[i+N]))
    plt.gray()
    bx.get_xaxis().set_visible(False)
    bx.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# ## Creating the Unet model

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization
from keras.optimizers import Adam
import tensorflow as tf

size = 32

# SSIM loss function
def ssim_loss(y_true, y_pred):
    return 1 - tf.reduce_mean(tf.image.ssim(y_true, y_pred, max_val=1.0))

def unet_model(input_shape=(size, size, 3)):
    inputs = Input(input_shape)

    # Contracting Path
    conv1 = Conv2D(8, 3, activation='relu', padding='same')(inputs)
    conv1 = Conv2D(8, 3, activation='relu', padding='same')(conv1)

    conv2 = Conv2D(16, 3, activation='relu', padding='same', strides=2)(conv1)
    conv2 = Conv2D(16, 3, activation='relu', padding='same')(conv2)

    conv3 = Conv2D(32, 3, activation='relu', padding='same', strides=2)(conv2)
    conv3 = Conv2D(32, 3, activation='relu', padding='same')(conv3)

    #conv4 = Conv2D(64, 3, activation='relu', padding='same', strides=2)(conv3)
    #conv4 = Conv2D(64, 3, activation='relu', padding='same')(conv4)

    #conv5 = concatenate([Conv2DTranspose(32, kernel_size=3, strides=2, activation='relu', padding='same')(conv4), conv3], axis=-1)
    #conv5 = Conv2D(32, 3, activation='relu', padding='same')(conv5)

    conv6 = concatenate([Conv2DTranspose(16, kernel_size=3, strides=2, activation='relu', padding='same')(conv3), conv2], axis=-1)
    conv6 = Conv2D(16, 3, activation='relu', padding='same')(conv6)

    conv7 = concatenate([Conv2DTranspose(8, kernel_size=3, strides=2, activation='relu', padding='same')(conv6), conv1], axis=-1)
    conv7 = Conv2D(8, 3, activation='relu', padding='same')(conv7)

    # Output Layer
    output = Conv2D(3, kernel_size=(3, 3), activation='sigmoid', padding='same')(conv7)

    model = Model(inputs=inputs, outputs=output)
    return model

# Usage example:
unet = unet_model()
unet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  conv2d (Conv2D)             (None, 32, 32, 8)            224       ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 8)            584       ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 16)           1168      ['conv2d_1[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 16)           2320      ['conv2d_2[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 32)             4640      ['conv2d_3[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 32)             9248      ['conv2d_4[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 16, 16, 16)           4624      ['conv2d_5[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 16, 16, 32)           0         ['conv2d_transpose[0][0]',
#                                                                      'conv2d_3[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 16)           4624      ['concatenate[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 32, 32, 8)            1160      ['conv2d_6[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 32, 32, 16)           0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 8)            1160      ['concatenate_1[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 3)            219       ['conv2d_7[0][0]']
#
# ==================================================================================================
# Total params: 29971 (117.07 KB)
# Trainable params: 29971 (117.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training the Unet model

# %%
from keras.optimizers import Adam
from tensorflow.keras import layers, losses

opt = Adam(learning_rate=0.0001)
unet.compile(optimizer=opt, loss=ssim_loss)  # Using SSIM loss function
#unet.compile(optimizer=opt, loss=losses.MeanSquaredError())
# Train your model as before
start = time.time()
model = unet.fit(train_input, train_output,
                epochs=100,
                shuffle=True,
                validation_data=(test_input, test_output),batch_size=32)
end = time.time()

print("The time of execution of above program is :",
      (end-start), "seconds")

unet.save(file_path + 'Model/unet_' + str(model_number) + '_rgb')

loss = model.history['loss']
loss = pd.DataFrame(loss)
loss.to_csv(file_path + 'Model/loss_'+ str(model_number) + '_rgb.csv')
val_loss = model.history['val_loss']
val_loss = pd.DataFrame(val_loss)
val_loss.to_csv(file_path  +'Model/val_loss_'+ str(model_number)+ '_rgb.csv')
# Out:
# Epoch 1/100
# 597/597 [==============================] - 15s 12ms/step - loss: 0.2407 - val_loss: 0.1607
# Epoch 2/100
# 597/597 [==============================] - 7s 11ms/step - loss: 0.1565 - val_loss: 0.1533
# Epoch 3/100
# 597/597 [==============================] - 6s 9ms/step - loss: 0.1513 - val_loss: 0.1483
# Epoch 4/100
# 597/597 [==============================] - 7s 11ms/step - loss: 0.1476 - val_loss: 0.1461
# Epoch 5/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1450 - val_loss: 0.1425
# Epoch 6/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1427 - val_loss: 0.1405
# Epoch 7/100
# 597/597 [==============================] - 6s 10ms/step - loss: 0.1409 - val_loss: 0.1414
# Epoch 8/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1397 - val_loss: 0.1385
# Epoch 9/100
# 597/597 [==============================] - 5s 9ms/step - loss: 0.1386 - val_loss: 0.1367
# Epoch 10/100
# 597/597 [==============================] - 6s 9ms/step - loss: 0.1377 - val_loss: 0.1363
# Epoch 11/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1369 - val_loss: 0.1355
# Epoch 12/100
# 597/597 [==============================] - 6s 10ms/step - loss: 0.1361 - val_loss: 0.1353
# Epoch 13/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1356 - val_loss: 0.1343
# Epoch 14/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1351 - val_loss: 0.1334
# Epoch 15/100
# 597/597 [==============================] - 6s 11ms/step - loss: 0.1345 - val_loss: 0.1330
# Epoch 16/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1340 - val_loss: 0.1326
# Epoch 17/100
# 597/597 [==============================] - 6s 9ms/step - loss: 0.1335 - val_loss: 0.1330
# Epoch 18/100
# 597/597 [==============================] - 6s 9ms/step - loss: 0.1332 - val_loss: 0.1319
# Epoch 19/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1326 - val_loss: 0.1311
# Epoch 20/100
# 597/597 [==============================] - 6s 11ms/step - loss: 0.1323 - val_loss: 0.1308
# Epoch 21/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1318 - val_loss: 0.1304
# Epoch 22/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1314 - val_loss: 0.1310
# Epoch 23/100
# 597/597 [==============================] - 7s 12ms/step - loss: 0.1311 - val_loss: 0.1300
# Epoch 24/100
# 597/597 [==============================] - 6s 9ms/step - loss: 0.1307 - val_loss: 0.1293
# Epoch 25/100
# 597/597 [==============================] - 6s 10ms/step - loss: 0.1303 - val_loss: 0.1294
# Epoch 26/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1302 - val_loss: 0.1295
# Epoch 27/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1299 - val_loss: 0.1293
# Epoch 28/100
# 597/597 [==============================] - 6s 10ms/step - loss: 0.1297 - val_loss: 0.1282
# Epoch 29/100
# 597/597 [==============================] - 5s 9ms/step - loss: 0.1293 - val_loss: 0.1289
# Epoch 30/100
# 597/597 [==============================] - 6s 9ms/step - loss: 0.1292 - val_loss: 0.1278
# Epoch 31/100
# 597/597 [==============================] - 5s 9ms/step - loss: 0.1287 - val_loss: 0.1283
# Epoch 32/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1286 - val_loss: 0.1274
# Epoch 33/100
# 597/597 [==============================] - 6s 11ms/step - loss: 0.1283 - val_loss: 0.1270
# Epoch 34/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1280 - val_loss: 0.1278
# Epoch 35/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1280 - val_loss: 0.1271
# Epoch 36/100
# 597/597 [==============================] - 6s 10ms/step - loss: 0.1277 - val_loss: 0.1273
# Epoch 37/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1274 - val_loss: 0.1263
# Epoch 38/100
# 597/597 [==============================] - 6s 11ms/step - loss: 0.1271 - val_loss: 0.1264
# Epoch 39/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1270 - val_loss: 0.1256
# Epoch 40/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1266 - val_loss: 0.1259
# Epoch 41/100
# 597/597 [==============================] - 6s 11ms/step - loss: 0.1265 - val_loss: 0.1257
# Epoch 42/100
# 597/597 [==============================] - 5s 9ms/step - loss: 0.1261 - val_loss: 0.1256
# Epoch 43/100
# 597/597 [==============================] - 6s 10ms/step - loss: 0.1261 - val_loss: 0.1266
# Epoch 44/100
# 597/597 [==============================] - 6s 9ms/step - loss: 0.1259 - val_loss: 0.1249
# Epoch 45/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1256 - val_loss: 0.1257
# Epoch 46/100
# 597/597 [==============================] - 6s 11ms/step - loss: 0.1253 - val_loss: 0.1251
# Epoch 47/100
# 597/597 [==============================] - 5s 9ms/step - loss: 0.1252 - val_loss: 0.1246
# Epoch 48/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1249 - val_loss: 0.1242
# Epoch 49/100
# 597/597 [==============================] - 6s 11ms/step - loss: 0.1248 - val_loss: 0.1240
# Epoch 50/100
# 597/597 [==============================] - 5s 9ms/step - loss: 0.1244 - val_loss: 0.1235
# Epoch 51/100
# 597/597 [==============================] - 6s 10ms/step - loss: 0.1243 - val_loss: 0.1233
# Epoch 52/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1243 - val_loss: 0.1236
# Epoch 53/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1239 - val_loss: 0.1229
# Epoch 54/100
# 597/597 [==============================] - 6s 11ms/step - loss: 0.1238 - val_loss: 0.1234
# Epoch 55/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1237 - val_loss: 0.1230
# Epoch 56/100
# 597/597 [==============================] - 6s 9ms/step - loss: 0.1237 - val_loss: 0.1230
# Epoch 57/100
# 597/597 [==============================] - 6s 10ms/step - loss: 0.1234 - val_loss: 0.1224
# Epoch 58/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1232 - val_loss: 0.1233
# Epoch 59/100
# 597/597 [==============================] - 6s 11ms/step - loss: 0.1229 - val_loss: 0.1234
# Epoch 60/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1229 - val_loss: 0.1228
# Epoch 61/100
# 597/597 [==============================] - 5s 9ms/step - loss: 0.1227 - val_loss: 0.1219
# Epoch 62/100
# 597/597 [==============================] - 6s 10ms/step - loss: 0.1226 - val_loss: 0.1218
# Epoch 63/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1223 - val_loss: 0.1217
# Epoch 64/100
# 597/597 [==============================] - 7s 11ms/step - loss: 0.1222 - val_loss: 0.1227
# Epoch 65/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1222 - val_loss: 0.1218
# Epoch 66/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1221 - val_loss: 0.1212
# Epoch 67/100
# 597/597 [==============================] - 6s 10ms/step - loss: 0.1218 - val_loss: 0.1212
# Epoch 68/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1218 - val_loss: 0.1213
# Epoch 69/100
# 597/597 [==============================] - 6s 10ms/step - loss: 0.1215 - val_loss: 0.1214
# Epoch 70/100
# 597/597 [==============================] - 5s 9ms/step - loss: 0.1214 - val_loss: 0.1210
# Epoch 71/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1213 - val_loss: 0.1212
# Epoch 72/100
# 597/597 [==============================] - 7s 11ms/step - loss: 0.1210 - val_loss: 0.1205
# Epoch 73/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1210 - val_loss: 0.1202
# Epoch 74/100
# 597/597 [==============================] - 5s 9ms/step - loss: 0.1210 - val_loss: 0.1202
# Epoch 75/100
# 597/597 [==============================] - 6s 10ms/step - loss: 0.1207 - val_loss: 0.1201
# Epoch 76/100
# 597/597 [==============================] - 5s 9ms/step - loss: 0.1207 - val_loss: 0.1203
# Epoch 77/100
# 597/597 [==============================] - 6s 11ms/step - loss: 0.1204 - val_loss: 0.1200
# Epoch 78/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1205 - val_loss: 0.1212
# Epoch 79/100
# 597/597 [==============================] - 5s 9ms/step - loss: 0.1204 - val_loss: 0.1204
# Epoch 80/100
# 597/597 [==============================] - 6s 11ms/step - loss: 0.1203 - val_loss: 0.1203
# Epoch 81/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1202 - val_loss: 0.1203
# Epoch 82/100
# 597/597 [==============================] - 6s 10ms/step - loss: 0.1202 - val_loss: 0.1211
# Epoch 83/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1198 - val_loss: 0.1197
# Epoch 84/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1198 - val_loss: 0.1196
# Epoch 85/100
# 597/597 [==============================] - 6s 11ms/step - loss: 0.1196 - val_loss: 0.1193
# Epoch 86/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1196 - val_loss: 0.1197
# Epoch 87/100
# 597/597 [==============================] - 6s 10ms/step - loss: 0.1195 - val_loss: 0.1196
# Epoch 88/100
# 597/597 [==============================] - 6s 9ms/step - loss: 0.1195 - val_loss: 0.1203
# Epoch 89/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1194 - val_loss: 0.1196
# Epoch 90/100
# 597/597 [==============================] - 6s 11ms/step - loss: 0.1192 - val_loss: 0.1200
# Epoch 91/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1193 - val_loss: 0.1193
# Epoch 92/100
# 597/597 [==============================] - 5s 9ms/step - loss: 0.1189 - val_loss: 0.1196
# Epoch 93/100
# 597/597 [==============================] - 6s 10ms/step - loss: 0.1191 - val_loss: 0.1188
# Epoch 94/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1189 - val_loss: 0.1203
# Epoch 95/100
# 597/597 [==============================] - 6s 10ms/step - loss: 0.1189 - val_loss: 0.1193
# Epoch 96/100
# 597/597 [==============================] - 5s 9ms/step - loss: 0.1188 - val_loss: 0.1194
# Epoch 97/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1185 - val_loss: 0.1187
# Epoch 98/100
# 597/597 [==============================] - 6s 11ms/step - loss: 0.1184 - val_loss: 0.1186
# Epoch 99/100
# 597/597 [==============================] - 5s 8ms/step - loss: 0.1185 - val_loss: 0.1192
# Epoch 100/100
# 597/597 [==============================] - 5s 9ms/step - loss: 0.1184 - val_loss: 0.1186
# The time of execution of above program is : 564.9514808654785 seconds

# %% [markdown]
# ## Testing the model

# %%
n_size = 32
size = 32

def rgb_L_ab(rgb_image, test_L):
    lab_array = color.rgb2lab(np.array(rgb_image))# Convert RGB to LAB colorspace
    lab_array[..., 0] = test_L #Change L channel to input
    rgb_array = color.lab2rgb(lab_array)# Convert back LAB to RGB colorspace
    rgb_array = (rgb_array * 255).astype(np.uint8)# Scale RGB values back to the range [0, 255]
    rgb_array = Image.fromarray(rgb_array, mode='RGB')# Convert RGB array back to image
    return rgb_array

def crop_(im):
    width, height = im.size
    data = []
    for j in range(0,int(height/n_size)):
        for i in range(0,int(width/n_size)):
            im1 = im.crop((0 + (n_size*i), 0 + (n_size*j), n_size + (n_size*i), n_size + (n_size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            data.append(im1)
    return data

#----------------READING THE TEST IMAGE--------------------#
filename = str("TEST_INPUT_[05] Comprimise-d.png")
test = contrast_stretch(Image.open(file_path+ "Testing/" + filename).convert('RGB'))
test_L = color.rgb2lab(np.array(test))
test_L = test_L[..., 0]
w_dirty, h_dirty = test.size
#----------------------------------------------------------#

autoencoder = keras.models.load_model(file_path + 'Model/unet_'+str(n_size)+'_rgb', custom_objects={'ssim_loss': ssim_loss})

xx = int(w_dirty/n_size)
final=[]

for portion in range(0,xx):
    im1 = test.crop((n_size*portion, 0, (n_size*portion) + n_size, h_dirty))
    w1, h1 = im1.size
    w = int(w1/n_size)
    h = int(h1/n_size)
    neverbeforeseen = np.array(crop_(im1))
    decoded_imgs = autoencoder.predict(neverbeforeseen)
    col = np.vstack((decoded_imgs[0],decoded_imgs[1]))
    for i in range(2,h):
        col = np.vstack((col,decoded_imgs[i]))
    y = col
    y = (y * 255).astype('uint8')
    if portion == 0:
        final = y
    if portion > 0:
        final = np.hstack((final,y))

#----------------TEST ON FULL RGB--------------------#
final_rgb = final
final_rgb = np.squeeze(final_rgb)
reconstructed_rgb = Image.fromarray(final_rgb)
reconstructed_rgb.save(file_path + "Testing/"+"Model_1_"+filename)
plt.figure(), plt.imshow(reconstructed_rgb)

#----------------TEST ON L from input and AB from convert RGB2LAB of model--------------------#
final_lab = rgb_L_ab(final, test_L)
final_lab = np.squeeze(final_lab)
reconstructed_lab = Image.fromarray(final_lab)
reconstructed_lab.save(file_path + "Testing/"+"Model_2_"+filename)
plt.figure(), plt.imshow(reconstructed_lab)
# Out:
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# (<Figure size 640x480 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x7a4504154b50>)

# %%
from PIL import Image
import numpy as np
from skimage.metrics import structural_similarity as ssim

# Function to open image and convert to numpy array
def load_image(image_path):
    image = Image.open(image_path).convert('RGB')  # Ensure image is in RGB mode
    return np.array(image)

image_path1 = file_path + 'Testing/TEST_OUTPUT_[05] Comprimise-d.png'
image_path2 = file_path + "Testing/"+"Model_2_"+filename

# Load images
image1 = load_image(image_path1)
image2 = load_image(image_path2)

# Ensure the images have the same dimensions
if image1.shape != image2.shape:
    raise ValueError("Input images must have the same dimensions.")

# Compute SSIM for each channel and average the results
ssim_index_r = ssim(image1[:, :, 0], image2[:, :, 0], data_range=image1[:, :, 0].max() - image1[:, :, 0].min())
ssim_index_g = ssim(image1[:, :, 1], image2[:, :, 1], data_range=image1[:, :, 1].max() - image1[:, :, 1].min())
ssim_index_b = ssim(image1[:, :, 2], image2[:, :, 2], data_range=image1[:, :, 2].max() - image1[:, :, 2].min())

ssim_index_rgb = (ssim_index_r + ssim_index_g + ssim_index_b) / 3

print(f"SSIM for R channel: {ssim_index_r}")
print(f"SSIM for G channel: {ssim_index_g}")
print(f"SSIM for B channel: {ssim_index_b}")
print(f"Average SSIM for RGB image(Method4): {ssim_index_rgb}")
# Out:
# SSIM for R channel: 0.7130053264855332
# SSIM for G channel: 0.7241008715987811
# SSIM for B channel: 0.7037764766497875
# Average SSIM for RGB image(Method4): 0.7136275582447006
