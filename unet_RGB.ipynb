# %% [markdown]
# <a href="https://colab.research.google.com/github/mgnarag/painting_restoration/blob/main/unet_RGB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !ls drive/My\ Drive
file_path = "/content/drive/MyDrive/Baumgartner screenshots/"

# %% [markdown]
# ## Installing packages

# %%
import time
import pandas as pd

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

from PIL import Image, ImageOps
import os
import numpy as np

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from scipy.ndimage import zoom

import cv2
from skimage import color

from tensorflow import keras
from PIL import Image, ImageOps
import numpy as np
import PIL
PIL.Image.MAX_IMAGE_PIXELS = 236958876
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Defining functions

# %%
def zoom_and_resize(img, zoom_factor):
    height, width = img.shape[:2]
    crop_top = int((height - height / zoom_factor) / 2)# Calculate the region to crop around the center
    crop_bottom = int(height - crop_top)
    crop_left = int((width - width / zoom_factor) / 2)
    crop_right = int(width - crop_left)
    cropped_image = img[crop_top:crop_bottom, crop_left:crop_right]    # Crop the image
    resized_image = cv2.resize(cropped_image, (width, height))# Resize the zoomed image back to the original dimensions
    return resized_image

def crop(im):
    width, height = im.size
    data = []
    step = int(size * 0.80)  # Adjust the step size for cropping
    for j in range(0, height, step):
        for i in range(0, width, step):
            if i + size <= width and j + size <= height:
                im1 = im.crop((i, j, i + size, j + size))
                im1 = np.array(im1).astype(np.float32)
                data.append(im1/255)
                #im1 = np.rot90(im1)
                #data.append(im1/255)
                #im1 = np.rot90(im1)
                #data.append(im1/255)
                #im1 = np.rot90(im1)
                #data.append(im1/255)
                for z in zoom_factor:
                    zoomed_img = zoom_and_resize(im1, z)
                    data.append(zoomed_img/255)
    return data

def contrast_stretch(image):
    img_array = np.array(image)
    for i in range(3):  # 3 channels: Red, Green, Blue
        # Compute min and max pixel intensity values for the channel
        min_val = np.min(img_array[:,:,i])
        max_val = np.max(img_array[:,:,i])
        # Apply contrast stretching
        img_array[:,:,i] = (img_array[:,:,i] - min_val) * (255.0 / (max_val - min_val))
    # Convert numpy array back to PIL Image
    stretched_image = Image.fromarray(np.uint8(img_array))
    return stretched_image

# %% [markdown]
# ## Preparing the training dataset

# %%
size = 32
model_number = size

zoom_factor = [1.50, 2.0,2.5,3.0]
input = []
output = []

input_folder_path = file_path + 'Training/input/'
output_folder_path = file_path + 'Training/output/'

# List all files in the directory and sort them alphabetically
input_files = sorted(os.listdir(input_folder_path))
output_files = sorted(os.listdir(output_folder_path))


for image_file in input_files:
    image_path = os.path.join(input_folder_path, image_file)
    image = contrast_stretch(Image.open(image_path).convert('RGB'))
    image = crop(image)
    input.extend(image)

for image_file in output_files:
    image_path = os.path.join(output_folder_path, image_file)
    image = Image.open(image_path).convert('RGB')
    image = crop(image)
    output.extend(image)
input = np.array(input)
output = np.array(output)

print("Done reading the input of size = ", input.shape)
print("Done reading the output of size = ", output.shape)

# Split the data into training and testing sets
train_input, test_input, train_output, test_output = train_test_split(
    input, output, test_size=0.2, random_state=42)

print("Done reading the train input of size = ", train_input.shape)
print("Done reading the test input of size = ", test_input.shape)
print("Done reading the train output of size = ", train_input.shape)
print("Done reading the test output of size = ", test_input.shape)

input = []
output = []
# Out:
# Done reading the input of size =  (40990, 32, 32, 3)
# Done reading the output of size =  (40990, 32, 32, 3)
# Done reading the train input of size =  (32792, 32, 32, 3)
# Done reading the test input of size =  (8198, 32, 32, 3)
# Done reading the train output of size =  (32792, 32, 32, 3)
# Done reading the test output of size =  (8198, 32, 32, 3)

# %%
N = 600
n = 10
plt.figure(figsize=(20, 4))
for i in range(0,10):
    ax = plt.subplot(2, n, i + 1)
    plt.title("input")
    plt.imshow((train_input[i+N]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    bx = plt.subplot(2, n, i + n + 1)
    plt.title("output")
    plt.imshow((train_output[i+N]))
    plt.gray()
    bx.get_xaxis().set_visible(False)
    bx.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# ## Creating the Unet model

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization
from keras.optimizers import Adam
import tensorflow as tf

size = 32

# SSIM loss function
def ssim_loss(y_true, y_pred):
    return 1 - tf.reduce_mean(tf.image.ssim(y_true, y_pred, max_val=1.0))

def unet_model(input_shape=(size, size, 3)):
    inputs = Input(input_shape)

    # Contracting Path
    conv1 = Conv2D(8, 3, activation='relu', padding='same')(inputs)
    conv1 = Conv2D(8, 3, activation='relu', padding='same')(conv1)

    conv2 = Conv2D(16, 3, activation='relu', padding='same', strides=2)(conv1)
    conv2 = Conv2D(16, 3, activation='relu', padding='same')(conv2)

    conv3 = Conv2D(32, 3, activation='relu', padding='same', strides=2)(conv2)
    conv3 = Conv2D(32, 3, activation='relu', padding='same')(conv3)

    #conv4 = Conv2D(64, 3, activation='relu', padding='same', strides=2)(conv3)
    #conv4 = Conv2D(64, 3, activation='relu', padding='same')(conv4)

    #conv5 = concatenate([Conv2DTranspose(32, kernel_size=3, strides=2, activation='relu', padding='same')(conv4), conv3], axis=-1)
    #conv5 = Conv2D(32, 3, activation='relu', padding='same')(conv5)

    conv6 = concatenate([Conv2DTranspose(16, kernel_size=3, strides=2, activation='relu', padding='same')(conv3), conv2], axis=-1)
    conv6 = Conv2D(16, 3, activation='relu', padding='same')(conv6)

    conv7 = concatenate([Conv2DTranspose(8, kernel_size=3, strides=2, activation='relu', padding='same')(conv6), conv1], axis=-1)
    conv7 = Conv2D(8, 3, activation='relu', padding='same')(conv7)

    # Output Layer
    output = Conv2D(3, kernel_size=(3, 3), activation='sigmoid', padding='same')(conv7)

    model = Model(inputs=inputs, outputs=output)
    return model

# Usage example:
unet = unet_model()
unet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  conv2d (Conv2D)             (None, 32, 32, 8)            224       ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 8)            584       ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 16)           1168      ['conv2d_1[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 16)           2320      ['conv2d_2[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 32)             4640      ['conv2d_3[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 32)             9248      ['conv2d_4[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 16, 16, 16)           4624      ['conv2d_5[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 16, 16, 32)           0         ['conv2d_transpose[0][0]',
#                                                                      'conv2d_3[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 16)           4624      ['concatenate[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 32, 32, 8)            1160      ['conv2d_6[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 32, 32, 16)           0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 8)            1160      ['concatenate_1[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 3)            219       ['conv2d_7[0][0]']
#
# ==================================================================================================
# Total params: 29971 (117.07 KB)
# Trainable params: 29971 (117.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training the Unet model

# %%
from keras.optimizers import Adam
from tensorflow.keras import layers, losses

opt = Adam(learning_rate=0.0001)
unet.compile(optimizer=opt, loss=ssim_loss)  # Using SSIM loss function
#unet.compile(optimizer=opt, loss=losses.MeanSquaredError())
# Train your model as before
start = time.time()
model = unet.fit(train_input, train_output,
                epochs=500,
                shuffle=True,
                validation_data=(test_input, test_output),batch_size=32)
end = time.time()

print("The time of execution of above program is :",
      (end-start), "seconds")

unet.save(file_path + 'Model/unet_' + str(model_number) + '_rgb')

loss = model.history['loss']
loss = pd.DataFrame(loss)
loss.to_csv(file_path + 'Model/loss_'+ str(model_number) + '_rgb.csv')
val_loss = model.history['val_loss']
val_loss = pd.DataFrame(val_loss)
val_loss.to_csv(file_path  +'Model/val_loss_'+ str(model_number)+ '_rgb.csv')
# Out:
# Epoch 1/500
# 1025/1025 [==============================] - 18s 11ms/step - loss: 0.2071 - val_loss: 0.1422
# Epoch 2/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1375 - val_loss: 0.1361
# Epoch 3/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1335 - val_loss: 0.1344
# Epoch 4/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.1311 - val_loss: 0.1317
# Epoch 5/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1291 - val_loss: 0.1300
# Epoch 6/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1274 - val_loss: 0.1289
# Epoch 7/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1259 - val_loss: 0.1266
# Epoch 8/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1246 - val_loss: 0.1256
# Epoch 9/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1235 - val_loss: 0.1255
# Epoch 10/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1227 - val_loss: 0.1244
# Epoch 11/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1220 - val_loss: 0.1228
# Epoch 12/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1213 - val_loss: 0.1243
# Epoch 13/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1209 - val_loss: 0.1249
# Epoch 14/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1201 - val_loss: 0.1219
# Epoch 15/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1196 - val_loss: 0.1219
# Epoch 16/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1194 - val_loss: 0.1201
# Epoch 17/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1187 - val_loss: 0.1212
# Epoch 18/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.1182 - val_loss: 0.1191
# Epoch 19/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1178 - val_loss: 0.1192
# Epoch 20/500
# 1025/1025 [==============================] - 11s 10ms/step - loss: 0.1174 - val_loss: 0.1195
# Epoch 21/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1171 - val_loss: 0.1180
# Epoch 22/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1168 - val_loss: 0.1178
# Epoch 23/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1163 - val_loss: 0.1184
# Epoch 24/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1160 - val_loss: 0.1177
# Epoch 25/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1155 - val_loss: 0.1174
# Epoch 26/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1152 - val_loss: 0.1169
# Epoch 27/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1149 - val_loss: 0.1157
# Epoch 28/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1147 - val_loss: 0.1172
# Epoch 29/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1143 - val_loss: 0.1152
# Epoch 30/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1140 - val_loss: 0.1169
# Epoch 31/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1138 - val_loss: 0.1165
# Epoch 32/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1135 - val_loss: 0.1148
# Epoch 33/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1131 - val_loss: 0.1150
# Epoch 34/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1129 - val_loss: 0.1140
# Epoch 35/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1126 - val_loss: 0.1149
# Epoch 36/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1124 - val_loss: 0.1139
# Epoch 37/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1121 - val_loss: 0.1145
# Epoch 38/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1118 - val_loss: 0.1136
# Epoch 39/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1116 - val_loss: 0.1136
# Epoch 40/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1114 - val_loss: 0.1126
# Epoch 41/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1112 - val_loss: 0.1138
# Epoch 42/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.1109 - val_loss: 0.1131
# Epoch 43/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1106 - val_loss: 0.1123
# Epoch 44/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1105 - val_loss: 0.1116
# Epoch 45/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.1103 - val_loss: 0.1126
# Epoch 46/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1101 - val_loss: 0.1119
# Epoch 47/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1099 - val_loss: 0.1114
# Epoch 48/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.1097 - val_loss: 0.1110
# Epoch 49/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.1095 - val_loss: 0.1109
# Epoch 50/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1094 - val_loss: 0.1115
# Epoch 51/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1091 - val_loss: 0.1105
# Epoch 52/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1091 - val_loss: 0.1106
# Epoch 53/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.1089 - val_loss: 0.1106
# Epoch 54/500
# 1025/1025 [==============================] - 11s 10ms/step - loss: 0.1087 - val_loss: 0.1111
# Epoch 55/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.1087 - val_loss: 0.1112
# Epoch 56/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1085 - val_loss: 0.1098
# Epoch 57/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.1083 - val_loss: 0.1098
# Epoch 58/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1082 - val_loss: 0.1094
# Epoch 59/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1080 - val_loss: 0.1096
# Epoch 60/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1079 - val_loss: 0.1093
# Epoch 61/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.1079 - val_loss: 0.1105
# Epoch 62/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1078 - val_loss: 0.1094
# Epoch 63/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1076 - val_loss: 0.1098
# Epoch 64/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1075 - val_loss: 0.1093
# Epoch 65/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1074 - val_loss: 0.1101
# Epoch 66/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1074 - val_loss: 0.1101
# Epoch 67/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1071 - val_loss: 0.1093
# Epoch 68/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.1072 - val_loss: 0.1095
# Epoch 69/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1071 - val_loss: 0.1091
# Epoch 70/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1069 - val_loss: 0.1084
# Epoch 71/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.1069 - val_loss: 0.1088
# Epoch 72/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1067 - val_loss: 0.1080
# Epoch 73/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1067 - val_loss: 0.1080
# Epoch 74/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.1064 - val_loss: 0.1080
# Epoch 75/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1065 - val_loss: 0.1084
# Epoch 76/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1064 - val_loss: 0.1090
# Epoch 77/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1063 - val_loss: 0.1082
# Epoch 78/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1062 - val_loss: 0.1081
# Epoch 79/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.1061 - val_loss: 0.1085
# Epoch 80/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.1060 - val_loss: 0.1084
# Epoch 81/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.1060 - val_loss: 0.1079
# Epoch 82/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1058 - val_loss: 0.1081
# Epoch 83/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1058 - val_loss: 0.1072
# Epoch 84/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1058 - val_loss: 0.1083
# Epoch 85/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1055 - val_loss: 0.1074
# Epoch 86/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1056 - val_loss: 0.1079
# Epoch 87/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.1054 - val_loss: 0.1073
# Epoch 88/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1053 - val_loss: 0.1070
# Epoch 89/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1054 - val_loss: 0.1070
# Epoch 90/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1052 - val_loss: 0.1078
# Epoch 91/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.1052 - val_loss: 0.1067
# Epoch 92/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1051 - val_loss: 0.1075
# Epoch 93/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.1050 - val_loss: 0.1067
# Epoch 94/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1049 - val_loss: 0.1067
# Epoch 95/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1047 - val_loss: 0.1087
# Epoch 96/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1048 - val_loss: 0.1065
# Epoch 97/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1046 - val_loss: 0.1067
# Epoch 98/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1047 - val_loss: 0.1064
# Epoch 99/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1045 - val_loss: 0.1074
# Epoch 100/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1044 - val_loss: 0.1066
# Epoch 101/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.1043 - val_loss: 0.1067
# Epoch 102/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.1045 - val_loss: 0.1062
# Epoch 103/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1042 - val_loss: 0.1073
# Epoch 104/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.1043 - val_loss: 0.1062
# Epoch 105/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1041 - val_loss: 0.1064
# Epoch 106/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1040 - val_loss: 0.1058
# Epoch 107/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1040 - val_loss: 0.1065
# Epoch 108/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1039 - val_loss: 0.1061
# Epoch 109/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1040 - val_loss: 0.1063
# Epoch 110/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1038 - val_loss: 0.1057
# Epoch 111/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.1037 - val_loss: 0.1062
# Epoch 112/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.1036 - val_loss: 0.1060
# Epoch 113/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.1036 - val_loss: 0.1054
# Epoch 114/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1036 - val_loss: 0.1058
# Epoch 115/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.1035 - val_loss: 0.1061
# Epoch 116/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1034 - val_loss: 0.1061
# Epoch 117/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1034 - val_loss: 0.1056
# Epoch 118/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.1033 - val_loss: 0.1053
# Epoch 119/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1033 - val_loss: 0.1053
# Epoch 120/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.1031 - val_loss: 0.1052
# Epoch 121/500
# 1025/1025 [==============================] - 11s 11ms/step - loss: 0.1031 - val_loss: 0.1056
# Epoch 122/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1031 - val_loss: 0.1052
# Epoch 123/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.1030 - val_loss: 0.1050
# Epoch 124/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.1030 - val_loss: 0.1051
# Epoch 125/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.1029 - val_loss: 0.1049
# Epoch 126/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.1029 - val_loss: 0.1050
# Epoch 127/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1030 - val_loss: 0.1048
# Epoch 128/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1027 - val_loss: 0.1051
# Epoch 129/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.1027 - val_loss: 0.1049
# Epoch 130/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.1026 - val_loss: 0.1064
# Epoch 131/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1026 - val_loss: 0.1049
# Epoch 132/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1026 - val_loss: 0.1049
# Epoch 133/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1025 - val_loss: 0.1046
# Epoch 134/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1025 - val_loss: 0.1047
# Epoch 135/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1024 - val_loss: 0.1043
# Epoch 136/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1023 - val_loss: 0.1047
# Epoch 137/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1023 - val_loss: 0.1047
# Epoch 138/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1023 - val_loss: 0.1048
# Epoch 139/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1022 - val_loss: 0.1043
# Epoch 140/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1022 - val_loss: 0.1048
# Epoch 141/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1021 - val_loss: 0.1053
# Epoch 142/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.1021 - val_loss: 0.1046
# Epoch 143/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.1021 - val_loss: 0.1054
# Epoch 144/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1020 - val_loss: 0.1040
# Epoch 145/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1019 - val_loss: 0.1044
# Epoch 146/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1019 - val_loss: 0.1043
# Epoch 147/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1019 - val_loss: 0.1046
# Epoch 148/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1018 - val_loss: 0.1046
# Epoch 149/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1018 - val_loss: 0.1042
# Epoch 150/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1017 - val_loss: 0.1049
# Epoch 151/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1016 - val_loss: 0.1057
# Epoch 152/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1016 - val_loss: 0.1042
# Epoch 153/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1017 - val_loss: 0.1035
# Epoch 154/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.1015 - val_loss: 0.1046
# Epoch 155/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.1015 - val_loss: 0.1047
# Epoch 156/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.1015 - val_loss: 0.1046
# Epoch 157/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1014 - val_loss: 0.1036
# Epoch 158/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.1014 - val_loss: 0.1042
# Epoch 159/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1013 - val_loss: 0.1038
# Epoch 160/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.1014 - val_loss: 0.1037
# Epoch 161/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1012 - val_loss: 0.1035
# Epoch 162/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1012 - val_loss: 0.1042
# Epoch 163/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1013 - val_loss: 0.1036
# Epoch 164/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1010 - val_loss: 0.1044
# Epoch 165/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1012 - val_loss: 0.1033
# Epoch 166/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1011 - val_loss: 0.1041
# Epoch 167/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.1011 - val_loss: 0.1045
# Epoch 168/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1011 - val_loss: 0.1046
# Epoch 169/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.1010 - val_loss: 0.1040
# Epoch 170/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1010 - val_loss: 0.1037
# Epoch 171/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.1010 - val_loss: 0.1035
# Epoch 172/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1009 - val_loss: 0.1034
# Epoch 173/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.1010 - val_loss: 0.1035
# Epoch 174/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1009 - val_loss: 0.1040
# Epoch 175/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1008 - val_loss: 0.1044
# Epoch 176/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1008 - val_loss: 0.1037
# Epoch 177/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1008 - val_loss: 0.1031
# Epoch 178/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.1007 - val_loss: 0.1034
# Epoch 179/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1008 - val_loss: 0.1038
# Epoch 180/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.1007 - val_loss: 0.1036
# Epoch 181/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1006 - val_loss: 0.1034
# Epoch 182/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.1006 - val_loss: 0.1028
# Epoch 183/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.1005 - val_loss: 0.1029
# Epoch 184/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1005 - val_loss: 0.1032
# Epoch 185/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1006 - val_loss: 0.1035
# Epoch 186/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1005 - val_loss: 0.1026
# Epoch 187/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1004 - val_loss: 0.1032
# Epoch 188/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1004 - val_loss: 0.1037
# Epoch 189/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.1004 - val_loss: 0.1043
# Epoch 190/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.1003 - val_loss: 0.1044
# Epoch 191/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.1003 - val_loss: 0.1032
# Epoch 192/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.1002 - val_loss: 0.1033
# Epoch 193/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.1003 - val_loss: 0.1034
# Epoch 194/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1003 - val_loss: 0.1032
# Epoch 195/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1002 - val_loss: 0.1033
# Epoch 196/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1002 - val_loss: 0.1038
# Epoch 197/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1001 - val_loss: 0.1026
# Epoch 198/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1001 - val_loss: 0.1034
# Epoch 199/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.1002 - val_loss: 0.1024
# Epoch 200/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.1002 - val_loss: 0.1026
# Epoch 201/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.1001 - val_loss: 0.1036
# Epoch 202/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0999 - val_loss: 0.1037
# Epoch 203/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.1000 - val_loss: 0.1030
# Epoch 204/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0999 - val_loss: 0.1035
# Epoch 205/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0999 - val_loss: 0.1033
# Epoch 206/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.1000 - val_loss: 0.1027
# Epoch 207/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0998 - val_loss: 0.1032
# Epoch 208/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0998 - val_loss: 0.1027
# Epoch 209/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.0998 - val_loss: 0.1033
# Epoch 210/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0998 - val_loss: 0.1030
# Epoch 211/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0997 - val_loss: 0.1021
# Epoch 212/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0997 - val_loss: 0.1031
# Epoch 213/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0997 - val_loss: 0.1031
# Epoch 214/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.0998 - val_loss: 0.1030
# Epoch 215/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0997 - val_loss: 0.1026
# Epoch 216/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0996 - val_loss: 0.1026
# Epoch 217/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.0996 - val_loss: 0.1029
# Epoch 218/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0996 - val_loss: 0.1024
# Epoch 219/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0996 - val_loss: 0.1025
# Epoch 220/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.0995 - val_loss: 0.1024
# Epoch 221/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0996 - val_loss: 0.1040
# Epoch 222/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0996 - val_loss: 0.1039
# Epoch 223/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.0995 - val_loss: 0.1027
# Epoch 224/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0995 - val_loss: 0.1025
# Epoch 225/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.0993 - val_loss: 0.1026
# Epoch 226/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0993 - val_loss: 0.1029
# Epoch 227/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0994 - val_loss: 0.1020
# Epoch 228/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.0992 - val_loss: 0.1019
# Epoch 229/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0991 - val_loss: 0.1035
# Epoch 230/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0993 - val_loss: 0.1025
# Epoch 231/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.0992 - val_loss: 0.1021
# Epoch 232/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0993 - val_loss: 0.1029
# Epoch 233/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0992 - val_loss: 0.1027
# Epoch 234/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0990 - val_loss: 0.1029
# Epoch 235/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0992 - val_loss: 0.1024
# Epoch 236/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0992 - val_loss: 0.1025
# Epoch 237/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.0992 - val_loss: 0.1020
# Epoch 238/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0990 - val_loss: 0.1025
# Epoch 239/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0991 - val_loss: 0.1028
# Epoch 240/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0990 - val_loss: 0.1020
# Epoch 241/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0991 - val_loss: 0.1019
# Epoch 242/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0990 - val_loss: 0.1024
# Epoch 243/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0990 - val_loss: 0.1023
# Epoch 244/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0989 - val_loss: 0.1024
# Epoch 245/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.0990 - val_loss: 0.1029
# Epoch 246/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0988 - val_loss: 0.1018
# Epoch 247/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0989 - val_loss: 0.1015
# Epoch 248/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0989 - val_loss: 0.1019
# Epoch 249/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0989 - val_loss: 0.1017
# Epoch 250/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0988 - val_loss: 0.1031
# Epoch 251/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0989 - val_loss: 0.1022
# Epoch 252/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0989 - val_loss: 0.1019
# Epoch 253/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0987 - val_loss: 0.1036
# Epoch 254/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.0987 - val_loss: 0.1022
# Epoch 255/500
# 1025/1025 [==============================] - 11s 11ms/step - loss: 0.0987 - val_loss: 0.1023
# Epoch 256/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0987 - val_loss: 0.1020
# Epoch 257/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.0988 - val_loss: 0.1021
# Epoch 258/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0986 - val_loss: 0.1017
# Epoch 259/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0986 - val_loss: 0.1016
# Epoch 260/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.0986 - val_loss: 0.1021
# Epoch 261/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0985 - val_loss: 0.1017
# Epoch 262/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0985 - val_loss: 0.1024
# Epoch 263/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0985 - val_loss: 0.1017
# Epoch 264/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0985 - val_loss: 0.1020
# Epoch 265/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0984 - val_loss: 0.1015
# Epoch 266/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0986 - val_loss: 0.1019
# Epoch 267/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0985 - val_loss: 0.1023
# Epoch 268/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0985 - val_loss: 0.1023
# Epoch 269/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0984 - val_loss: 0.1027
# Epoch 270/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0984 - val_loss: 0.1033
# Epoch 271/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0983 - val_loss: 0.1020
# Epoch 272/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.0983 - val_loss: 0.1023
# Epoch 273/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0983 - val_loss: 0.1016
# Epoch 274/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0983 - val_loss: 0.1020
# Epoch 275/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0982 - val_loss: 0.1019
# Epoch 276/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0984 - val_loss: 0.1011
# Epoch 277/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0981 - val_loss: 0.1017
# Epoch 278/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0982 - val_loss: 0.1020
# Epoch 279/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0983 - val_loss: 0.1017
# Epoch 280/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.0982 - val_loss: 0.1017
# Epoch 281/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0982 - val_loss: 0.1016
# Epoch 282/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0983 - val_loss: 0.1019
# Epoch 283/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.0981 - val_loss: 0.1020
# Epoch 284/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0983 - val_loss: 0.1015
# Epoch 285/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0981 - val_loss: 0.1023
# Epoch 286/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.0982 - val_loss: 0.1023
# Epoch 287/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0981 - val_loss: 0.1017
# Epoch 288/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0980 - val_loss: 0.1019
# Epoch 289/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0980 - val_loss: 0.1015
# Epoch 290/500
# 1025/1025 [==============================] - 11s 10ms/step - loss: 0.0980 - val_loss: 0.1022
# Epoch 291/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0979 - val_loss: 0.1014
# Epoch 292/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0980 - val_loss: 0.1021
# Epoch 293/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0979 - val_loss: 0.1017
# Epoch 294/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0980 - val_loss: 0.1012
# Epoch 295/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.0979 - val_loss: 0.1019
# Epoch 296/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0980 - val_loss: 0.1012
# Epoch 297/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.0979 - val_loss: 0.1025
# Epoch 298/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0979 - val_loss: 0.1009
# Epoch 299/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0977 - val_loss: 0.1013
# Epoch 300/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0980 - val_loss: 0.1020
# Epoch 301/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0978 - val_loss: 0.1024
# Epoch 302/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0978 - val_loss: 0.1013
# Epoch 303/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0977 - val_loss: 0.1011
# Epoch 304/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0977 - val_loss: 0.1012
# Epoch 305/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0978 - val_loss: 0.1012
# Epoch 306/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0978 - val_loss: 0.1015
# Epoch 307/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0977 - val_loss: 0.1011
# Epoch 308/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0977 - val_loss: 0.1016
# Epoch 309/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.0976 - val_loss: 0.1011
# Epoch 310/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0976 - val_loss: 0.1012
# Epoch 311/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0977 - val_loss: 0.1014
# Epoch 312/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0977 - val_loss: 0.1012
# Epoch 313/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0976 - val_loss: 0.1013
# Epoch 314/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0975 - val_loss: 0.1014
# Epoch 315/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.0975 - val_loss: 0.1034
# Epoch 316/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0975 - val_loss: 0.1015
# Epoch 317/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0976 - val_loss: 0.1012
# Epoch 318/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.0975 - val_loss: 0.1012
# Epoch 319/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0975 - val_loss: 0.1010
# Epoch 320/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0975 - val_loss: 0.1021
# Epoch 321/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.0975 - val_loss: 0.1011
# Epoch 322/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0974 - val_loss: 0.1008
# Epoch 323/500
# 1025/1025 [==============================] - 11s 11ms/step - loss: 0.0976 - val_loss: 0.1010
# Epoch 324/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0975 - val_loss: 0.1015
# Epoch 325/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0974 - val_loss: 0.1012
# Epoch 326/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0974 - val_loss: 0.1011
# Epoch 327/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.0973 - val_loss: 0.1007
# Epoch 328/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0973 - val_loss: 0.1017
# Epoch 329/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0973 - val_loss: 0.1010
# Epoch 330/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.0973 - val_loss: 0.1015
# Epoch 331/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0974 - val_loss: 0.1014
# Epoch 332/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0972 - val_loss: 0.1012
# Epoch 333/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0973 - val_loss: 0.1007
# Epoch 334/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0973 - val_loss: 0.1008
# Epoch 335/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0972 - val_loss: 0.1011
# Epoch 336/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0972 - val_loss: 0.1012
# Epoch 337/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0972 - val_loss: 0.1012
# Epoch 338/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.0972 - val_loss: 0.1011
# Epoch 339/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0972 - val_loss: 0.1014
# Epoch 340/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0971 - val_loss: 0.1012
# Epoch 341/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.0972 - val_loss: 0.1011
# Epoch 342/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0972 - val_loss: 0.1007
# Epoch 343/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0972 - val_loss: 0.1006
# Epoch 344/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.0971 - val_loss: 0.1014
# Epoch 345/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0971 - val_loss: 0.1019
# Epoch 346/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0971 - val_loss: 0.1007
# Epoch 347/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0970 - val_loss: 0.1006
# Epoch 348/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0970 - val_loss: 0.1014
# Epoch 349/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0970 - val_loss: 0.1005
# Epoch 350/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0970 - val_loss: 0.1014
# Epoch 351/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0970 - val_loss: 0.1005
# Epoch 352/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0971 - val_loss: 0.1015
# Epoch 353/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0969 - val_loss: 0.1008
# Epoch 354/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0969 - val_loss: 0.1014
# Epoch 355/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.0969 - val_loss: 0.1005
# Epoch 356/500
# 1025/1025 [==============================] - 11s 11ms/step - loss: 0.0970 - val_loss: 0.1010
# Epoch 357/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0969 - val_loss: 0.1017
# Epoch 358/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0969 - val_loss: 0.1008
# Epoch 359/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0969 - val_loss: 0.1009
# Epoch 360/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0968 - val_loss: 0.1008
# Epoch 361/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0968 - val_loss: 0.1007
# Epoch 362/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0968 - val_loss: 0.1005
# Epoch 363/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0968 - val_loss: 0.1013
# Epoch 364/500
# 1025/1025 [==============================] - 8s 8ms/step - loss: 0.0968 - val_loss: 0.1008
# Epoch 365/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0969 - val_loss: 0.1004
# Epoch 366/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0968 - val_loss: 0.1004
# Epoch 367/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0969 - val_loss: 0.1015
# Epoch 368/500
# 1025/1025 [==============================] - 11s 11ms/step - loss: 0.0967 - val_loss: 0.1012
# Epoch 369/500
# 1025/1025 [==============================] - 11s 10ms/step - loss: 0.0968 - val_loss: 0.1005
# Epoch 370/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0968 - val_loss: 0.1009
# Epoch 371/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0967 - val_loss: 0.1004
# Epoch 372/500
# 1025/1025 [==============================] - 11s 11ms/step - loss: 0.0967 - val_loss: 0.1004
# Epoch 373/500
# 1025/1025 [==============================] - 11s 10ms/step - loss: 0.0966 - val_loss: 0.1005
# Epoch 374/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0967 - val_loss: 0.1006
# Epoch 375/500
# 1025/1025 [==============================] - 11s 10ms/step - loss: 0.0966 - val_loss: 0.1006
# Epoch 376/500
# 1025/1025 [==============================] - 11s 10ms/step - loss: 0.0967 - val_loss: 0.1013
# Epoch 377/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0966 - val_loss: 0.1007
# Epoch 378/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0965 - val_loss: 0.1003
# Epoch 379/500
# 1025/1025 [==============================] - 11s 10ms/step - loss: 0.0966 - val_loss: 0.1007
# Epoch 380/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0966 - val_loss: 0.1002
# Epoch 381/500
# 1025/1025 [==============================] - 11s 10ms/step - loss: 0.0966 - val_loss: 0.1009
# Epoch 382/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0965 - val_loss: 0.1011
# Epoch 383/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0965 - val_loss: 0.1003
# Epoch 384/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0966 - val_loss: 0.1003
# Epoch 385/500
# 1025/1025 [==============================] - 11s 10ms/step - loss: 0.0965 - val_loss: 0.1002
# Epoch 386/500
# 1025/1025 [==============================] - 11s 11ms/step - loss: 0.0965 - val_loss: 0.1003
# Epoch 387/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0966 - val_loss: 0.1006
# Epoch 388/500
# 1025/1025 [==============================] - 12s 11ms/step - loss: 0.0966 - val_loss: 0.1005
# Epoch 389/500
# 1025/1025 [==============================] - 11s 10ms/step - loss: 0.0965 - val_loss: 0.1009
# Epoch 390/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0965 - val_loss: 0.1008
# Epoch 391/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0964 - val_loss: 0.1003
# Epoch 392/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0964 - val_loss: 0.1011
# Epoch 393/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0964 - val_loss: 0.1008
# Epoch 394/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0964 - val_loss: 0.1005
# Epoch 395/500
# 1025/1025 [==============================] - 11s 10ms/step - loss: 0.0963 - val_loss: 0.1000
# Epoch 396/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0964 - val_loss: 0.1006
# Epoch 397/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0964 - val_loss: 0.1012
# Epoch 398/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0964 - val_loss: 0.1008
# Epoch 399/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0964 - val_loss: 0.1008
# Epoch 400/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0964 - val_loss: 0.1034
# Epoch 401/500
# 1025/1025 [==============================] - 11s 11ms/step - loss: 0.0963 - val_loss: 0.1003
# Epoch 402/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0963 - val_loss: 0.1005
# Epoch 403/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0964 - val_loss: 0.1009
# Epoch 404/500
# 1025/1025 [==============================] - 11s 10ms/step - loss: 0.0963 - val_loss: 0.1009
# Epoch 405/500
# 1025/1025 [==============================] - 11s 10ms/step - loss: 0.0963 - val_loss: 0.1022
# Epoch 406/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0963 - val_loss: 0.1027
# Epoch 407/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0962 - val_loss: 0.1005
# Epoch 408/500
# 1025/1025 [==============================] - 11s 10ms/step - loss: 0.0963 - val_loss: 0.1005
# Epoch 409/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.0962 - val_loss: 0.1007
# Epoch 410/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0962 - val_loss: 0.1005
# Epoch 411/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0961 - val_loss: 0.1002
# Epoch 412/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0961 - val_loss: 0.1010
# Epoch 413/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0962 - val_loss: 0.1003
# Epoch 414/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0961 - val_loss: 0.1003
# Epoch 415/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0963 - val_loss: 0.1003
# Epoch 416/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0962 - val_loss: 0.1001
# Epoch 417/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0962 - val_loss: 0.1003
# Epoch 418/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0962 - val_loss: 0.1009
# Epoch 419/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0962 - val_loss: 0.1016
# Epoch 420/500
# 1025/1025 [==============================] - 12s 11ms/step - loss: 0.0962 - val_loss: 0.0998
# Epoch 421/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0961 - val_loss: 0.1018
# Epoch 422/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0963 - val_loss: 0.1000
# Epoch 423/500
# 1025/1025 [==============================] - 11s 10ms/step - loss: 0.0961 - val_loss: 0.1010
# Epoch 424/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0962 - val_loss: 0.1005
# Epoch 425/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0961 - val_loss: 0.1000
# Epoch 426/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0961 - val_loss: 0.1001
# Epoch 427/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0960 - val_loss: 0.1003
# Epoch 428/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0961 - val_loss: 0.1000
# Epoch 429/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0960 - val_loss: 0.1025
# Epoch 430/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0960 - val_loss: 0.1016
# Epoch 431/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0959 - val_loss: 0.1000
# Epoch 432/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0958 - val_loss: 0.1006
# Epoch 433/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0961 - val_loss: 0.1000
# Epoch 434/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0960 - val_loss: 0.1001
# Epoch 435/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0960 - val_loss: 0.1003
# Epoch 436/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0959 - val_loss: 0.1005
# Epoch 437/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0959 - val_loss: 0.1007
# Epoch 438/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0960 - val_loss: 0.1005
# Epoch 439/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0959 - val_loss: 0.1001
# Epoch 440/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0959 - val_loss: 0.1014
# Epoch 441/500
# 1025/1025 [==============================] - 11s 10ms/step - loss: 0.0959 - val_loss: 0.1001
# Epoch 442/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0958 - val_loss: 0.1002
# Epoch 443/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0959 - val_loss: 0.1004
# Epoch 444/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0959 - val_loss: 0.1001
# Epoch 445/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0958 - val_loss: 0.1001
# Epoch 446/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0958 - val_loss: 0.1003
# Epoch 447/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0958 - val_loss: 0.1009
# Epoch 448/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.0957 - val_loss: 0.1003
# Epoch 449/500
# 1025/1025 [==============================] - 11s 10ms/step - loss: 0.0958 - val_loss: 0.0998
# Epoch 450/500
# 1025/1025 [==============================] - 11s 10ms/step - loss: 0.0957 - val_loss: 0.1004
# Epoch 451/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0957 - val_loss: 0.1001
# Epoch 452/500
# 1025/1025 [==============================] - 11s 11ms/step - loss: 0.0957 - val_loss: 0.1005
# Epoch 453/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0957 - val_loss: 0.1003
# Epoch 454/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0959 - val_loss: 0.1002
# Epoch 455/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0958 - val_loss: 0.1008
# Epoch 456/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0957 - val_loss: 0.1008
# Epoch 457/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0958 - val_loss: 0.1004
# Epoch 458/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0958 - val_loss: 0.1001
# Epoch 459/500
# 1025/1025 [==============================] - 11s 11ms/step - loss: 0.0957 - val_loss: 0.1007
# Epoch 460/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0957 - val_loss: 0.1000
# Epoch 461/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0957 - val_loss: 0.0996
# Epoch 462/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0957 - val_loss: 0.0996
# Epoch 463/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0957 - val_loss: 0.1005
# Epoch 464/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.0957 - val_loss: 0.0998
# Epoch 465/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0957 - val_loss: 0.0999
# Epoch 466/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0956 - val_loss: 0.0999
# Epoch 467/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0958 - val_loss: 0.1002
# Epoch 468/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0957 - val_loss: 0.1013
# Epoch 469/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0956 - val_loss: 0.1004
# Epoch 470/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0957 - val_loss: 0.1002
# Epoch 471/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0956 - val_loss: 0.0999
# Epoch 472/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0956 - val_loss: 0.0996
# Epoch 473/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0956 - val_loss: 0.0999
# Epoch 474/500
# 1025/1025 [==============================] - 11s 10ms/step - loss: 0.0956 - val_loss: 0.1003
# Epoch 475/500
# 1025/1025 [==============================] - 10s 9ms/step - loss: 0.0956 - val_loss: 0.0998
# Epoch 476/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0956 - val_loss: 0.0994
# Epoch 477/500
# 1025/1025 [==============================] - 11s 10ms/step - loss: 0.0955 - val_loss: 0.1000
# Epoch 478/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0955 - val_loss: 0.1002
# Epoch 479/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0955 - val_loss: 0.0996
# Epoch 480/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0956 - val_loss: 0.1004
# Epoch 481/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0955 - val_loss: 0.0998
# Epoch 482/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0955 - val_loss: 0.1000
# Epoch 483/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0954 - val_loss: 0.0997
# Epoch 484/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0956 - val_loss: 0.0998
# Epoch 485/500
# 1025/1025 [==============================] - 11s 11ms/step - loss: 0.0955 - val_loss: 0.1002
# Epoch 486/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0955 - val_loss: 0.1000
# Epoch 487/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0954 - val_loss: 0.1008
# Epoch 488/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.0954 - val_loss: 0.0996
# Epoch 489/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0954 - val_loss: 0.0998
# Epoch 490/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0954 - val_loss: 0.0999
# Epoch 491/500
# 1025/1025 [==============================] - 9s 8ms/step - loss: 0.0954 - val_loss: 0.0998
# Epoch 492/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0955 - val_loss: 0.1001
# Epoch 493/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0955 - val_loss: 0.0996
# Epoch 494/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0953 - val_loss: 0.0998
# Epoch 495/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0954 - val_loss: 0.1002
# Epoch 496/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0953 - val_loss: 0.1004
# Epoch 497/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0953 - val_loss: 0.1010
# Epoch 498/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0954 - val_loss: 0.1002
# Epoch 499/500
# 1025/1025 [==============================] - 10s 10ms/step - loss: 0.0953 - val_loss: 0.1000
# Epoch 500/500
# 1025/1025 [==============================] - 9s 9ms/step - loss: 0.0954 - val_loss: 0.0996
# The time of execution of above program is : 4705.779800415039 seconds

# %% [markdown]
# ## Testing the model

# %%
n_size = 32
size = 32

def rgb_L_ab(rgb_image, test_L):
    lab_array = color.rgb2lab(np.array(rgb_image))# Convert RGB to LAB colorspace
    lab_array[..., 0] = test_L #Change L channel to input
    rgb_array = color.lab2rgb(lab_array)# Convert back LAB to RGB colorspace
    rgb_array = (rgb_array * 255).astype(np.uint8)# Scale RGB values back to the range [0, 255]
    rgb_array = Image.fromarray(rgb_array, mode='RGB')# Convert RGB array back to image
    return rgb_array

def crop_(im):
    width, height = im.size
    data = []
    for j in range(0,int(height/n_size)):
        for i in range(0,int(width/n_size)):
            im1 = im.crop((0 + (n_size*i), 0 + (n_size*j), n_size + (n_size*i), n_size + (n_size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            data.append(im1)
    return data

#----------------READING THE TEST IMAGE--------------------#
filename = str("[21]TheResistor-Before.png")
test = contrast_stretch(Image.open(file_path+ "Testing/" + filename).convert('RGB'))
test_L = color.rgb2lab(np.array(test))
test_L = test_L[..., 0]
w_dirty, h_dirty = test.size
#----------------------------------------------------------#

autoencoder = keras.models.load_model(file_path + 'Model/unet_'+str(n_size)+'_rgb', custom_objects={'ssim_loss': ssim_loss})

xx = int(w_dirty/n_size)
final=[]

for portion in range(0,xx):
    im1 = test.crop((n_size*portion, 0, (n_size*portion) + n_size, h_dirty))
    w1, h1 = im1.size
    w = int(w1/n_size)
    h = int(h1/n_size)
    neverbeforeseen = np.array(crop_(im1))
    decoded_imgs = autoencoder.predict(neverbeforeseen)
    col = np.vstack((decoded_imgs[0],decoded_imgs[1]))
    for i in range(2,h):
        col = np.vstack((col,decoded_imgs[i]))
    y = col
    y = (y * 255).astype('uint8')
    if portion == 0:
        final = y
    if portion > 0:
        final = np.hstack((final,y))

#----------------TEST ON FULL RGB--------------------#
final_rgb = final
final_rgb = np.squeeze(final_rgb)
reconstructed_rgb = Image.fromarray(final_rgb)
reconstructed_rgb.save(file_path + "Testing/"+"Model_1_"+filename)
plt.figure(), plt.imshow(reconstructed_rgb)

#----------------TEST ON L from input and AB from convert RGB2LAB of model--------------------#
final_lab = rgb_L_ab(final, test_L)
final_lab = np.squeeze(final_lab)
reconstructed_lab = Image.fromarray(final_lab)
reconstructed_lab.save(file_path + "Testing/"+"Model_2_"+filename)
plt.figure(), plt.imshow(reconstructed_lab)
# Out:
# 2/2 [==============================] - 1s 480ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 11ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-9ffea40e76fd> in <cell line: 62>()
#      60
#      61 #----------------TEST ON L from input and AB from convert RGB2LAB of model--------------------#
# ---> 62 final_lab = rgb_L_ab(final, test_L)
#      63 final_lab = np.squeeze(final_lab)
#      64 reconstructed_lab = Image.fromarray(final_lab)
#
# <ipython-input-19-9ffea40e76fd> in rgb_L_ab(rgb_image, test_L)
#       4 def rgb_L_ab(rgb_image, test_L):
#       5     lab_array = color.rgb2lab(np.array(rgb_image))# Convert RGB to LAB colorspace
# ----> 6     lab_array[..., 0] = test_L #Change L channel to input
#       7     rgb_array = color.lab2rgb(lab_array)# Convert back LAB to RGB colorspace
#       8     rgb_array = (rgb_array * 255).astype(np.uint8)# Scale RGB values back to the range [0, 255]
#
# ValueError: could not broadcast input array from shape (1306,1166) into shape (1280,1152)

# %%
from PIL import Image
import numpy as np
from skimage.metrics import structural_similarity as ssim

# Function to open image and convert to numpy array
def load_image(image_path):
    image = Image.open(image_path).convert('RGB')  # Ensure image is in RGB mode
    return np.array(image)

image_path1 = file_path + 'Testing/TEST_OUTPUT_[05] Comprimise-d.png'
image_path2 = file_path + "Testing/"+"Model_2_"+filename

# Load images
image1 = load_image(image_path1)
image2 = load_image(image_path2)

# Ensure the images have the same dimensions
if image1.shape != image2.shape:
    raise ValueError("Input images must have the same dimensions.")

# Compute SSIM for each channel and average the results
ssim_index_r = ssim(image1[:, :, 0], image2[:, :, 0], data_range=image1[:, :, 0].max() - image1[:, :, 0].min())
ssim_index_g = ssim(image1[:, :, 1], image2[:, :, 1], data_range=image1[:, :, 1].max() - image1[:, :, 1].min())
ssim_index_b = ssim(image1[:, :, 2], image2[:, :, 2], data_range=image1[:, :, 2].max() - image1[:, :, 2].min())

ssim_index_rgb = (ssim_index_r + ssim_index_g + ssim_index_b) / 3

print(f"SSIM for R channel: {ssim_index_r}")
print(f"SSIM for G channel: {ssim_index_g}")
print(f"SSIM for B channel: {ssim_index_b}")
print(f"Average SSIM for RGB image(Method4): {ssim_index_rgb}")
# Out:
# SSIM for R channel: 0.7149119616494869
# SSIM for G channel: 0.7248725980217174
# SSIM for B channel: 0.7075906602808648
# Average SSIM for RGB image(Method4): 0.7157917399840231
