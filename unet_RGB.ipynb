# %% [markdown]
# <a href="https://colab.research.google.com/github/mgnarag/painting_restoration/blob/main/unet_RGB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls drive/My\ Drive
file_path = "/content/drive/MyDrive/Baumgartner screenshots/"
# Out:
# '107.1 syllabus 1SAY1920 FINAL.gdoc'
# '1C-01 Narag et al (1).pdf'
# '1C-01 Narag et al.pdf'
# '1FA971504AC646559D05A8ED6341AFB3[1025340].png'
# '1H-04 Narag et al.pdf'
#  20220802_182749.heic
#  20220802_182831.heic
#  20220802_183259.heic
#  20220803_125819.heic
#  20220803_125842.heic
#  20220803_144229.heic
#  20220803_144422.heic
#  20220803_160724.heic
#  20220803_160751.heic
#  20220803_165240.heic
#  20220803_165318.heic
#  20220803_174701.heic
#  20220803_174706.heic
#  20220804_175217.heic
#  20220804_175443.heic
#  20220804_175616.heic
#  20220804_181917.heic
#  20220804_182007.heic
#  20220804_182117.heic
#  2S22-23_LE3-Regular-Set-A-FINAL-KEY.pdf
# '3 classes (polarized)CM_alexnet.png'
# '3 classes (polarized)CM_vgg.png'
# 'A4_Physics 71 TWHFU-3_gradesheet (1).pdf'
# 'A4_Physics 71 TWHFU-3_officialgrades (1).pdf'
# 'A4_Physics 71 TWHFU-3_officialgrades.gdoc'
# 'Abstract - NARAG, Mark Jeremy.pdf'
# 'Annex 1 (copy of Journal).pdf'
# 'Annex 2 (Proof of employments).pdf'
# 'App Physics 181 THY-FX-2_studentcontactlist.xlsx'
#  Architectural_designs
# 'Arki abstract.pdf'
# 'Arki full paper.pdf'
# '[ART] Example of Objectives - Activities - Exp Output OPTIKAL WBS version 2.gsheet'
#  autoencoder_fine_tuned_6
# 'autoencoder_fine_tuned_6 (1)'
#  autoencoder_fine_tuned_6_b
# 'Baumgartner screenshots'
# 'Binarizing architectural drawings'
#  classification_report_nonTL.xlsx
#  classification_report.xlsx
#  Classroom
# 'CLEAN32_AB_INPUT_[09] Preserve and Protect.png'
# 'CLEAN32_AB_TEST_INPUT_[04] Coming into Bloom_V1.png'
# 'CLEAN32LAB_Copy of [05] Comprimise-d - Before.png'
# 'CLEAN_TEST_INPUT_[04] Coming into Bloom.png'
# 'Colab Notebooks'
# 'Color Difference Specification 2016.pptx'
#  confusion_matrix_nonTL.png
#  confusion_matrix_nonTL.xlsx
#  CS284
#  CS_NIP_201819_S2_BS_AppliedPhysics_Narag_Mark_Jeremy.pdf
#  D54dUVpU8AIZzoD.jpeg
#  Data.tex
# 'Dormitory Stay Request MNarag.docx.pdf'
# '[DRAFT-ART] UP Intelligent Systems Center Research Grant Application - Preview.docx'
#  DrzPc0sUwAAyQHi.jpeg
#  DvO96koV4AAD6PP.jpeg
# 'DvO976tVAAEQ9ym (1).jpeg'
#  DvO976tVAAEQ9ym.jpeg
# 'Employment Survey.gdoc'
#  Fast-Dreambooth
# 'FBC-2_Banez (1).pdf'
#  FBC-2_Banez.pdf
#  FdUaD2nUcAAki1b.jpeg
# 'Figure 1.png'
# 'Figure 2.png'
# 'fingerprint (1).pb'
# 'fingerprint (2).pb'
# 'fingerprint (3).pb'
# 'fingerprint (4).pb'
# 'fingerprint (5).pb'
# 'fingerprint (6).pb'
#  fingerprint.pb
# 'Form5a and Grades.zip'
#  Fringes.zip
#  FSR_120201_NARAG_MARK_JEREMY_GACIAS_NIP.pdf
#  FSR_120202_NARAG_MARK_JEREMY_GACIAS_NIP.pdf
#  FSR_120212_NARAG_MARK_JEREMY_GACIAS_NIP.pdf
#  FSR_120221_NARAG_MARK_JEREMY_GACIAS_NIP.pdf
# 'Geology (Ate Grass)'
# 'Geology (Ate Grass) (1)'
# 'Getting started.pdf'
#  IMG_4258.HEIC
#  IMG_4259.HEIC
#  IMG_4260.HEIC
#  IMG_4261.HEIC
#  IMG_4262.HEIC
#  IMG_4263.HEIC
#  IMG_4288.HEIC
#  IMG_5634.JPG
#  IMG_6572.jpeg
#  IMG_6578.jpeg
# 'IMG_6587 (1).jpeg'
#  IMG_6587.jpeg
#  IPA-Form4.1-2021Rev072021-1.pdf
#  IPA-Form4.2-2021Rev072021.docx
#  IPA-Form4.3-2021Rev072021.pdf
# 'item sample.tex'
# 'item template.tex'
# 'Jas Jem utang.gsheet'
#  Jem_face
# 'JFR Reduced Fees for 1st Sem AY 20-21.zip'
# 'Lecture 22 - Torque.pptx'
# 'Lecture 23 - Dynamics of Rotation.pptx'
# 'Lecture 24 - Angular Momentum.pptx'
# 'Lecture 25 - Equilibrium and Center of Gravity.pptx'
# 'Lecture 26 - Density and Pressure in a Fluid.pptx'
# 'Lecture 27 - Buoyancy.pptx'
# 'LRM_20220804_195432 (1).dng'
#  LRM_20220804_195432.dng
#  LRM_20220804_195500.dng
#  LRM_20220804_195546.dng
#  LRM_20220805_113837.dng
#  LRM_20220805_142837.dng
#  LRM_20220805_143054.dng
#  LRM_20220805_143817.dng
# 'MALIPOL_CHAE ANN.pdf'
#  Metric_100dpi.csv
#  Metric_500.csv
# 'NARAG_MARKJEREMY (1).BC.pdf'
#  NARAG_MARKJEREMY.BC.pdf
#  NARAG_MARKJEREMY.CC.png
#  NARAG_MARKJEREMY.dcog.pdf
#  NARAG_MARKJEREMY.DC.pdf
#  NARAG_MARKJEREMY.FL.pdf
#  NARAG_MARKJEREMY.Form1.1.pdf
#  NARAG_MARKJEREMY.POS.pdf
#  NARAG_MARKJEREMY.SD.pdf
#  NARAG_MARKJEREMY.TCGTOR.pdf
# '[NARAG] Physics 242 Final Report.pdf'
# '[NARAG] Physics 242 PS 1.pdf'
# '[NARAG] Physics 242 PS 2.pdf'
# 'Narag SPP Cert.pdf'
#  NARAG_Travel-Report-Form-2019.pdf
# 'NIP COVID-19 Case Report Form.gform'
# 'NIP COVID-19 Case Report Form (Responses).gsheet'
# 'NIP COVID19 Report.gsheet'
# 'NIP Year End Party 2022'
#  NRAG_MARKJEREMY.OTRTCG.pdf
# 'Optics in Art and Art Analysis (1).pptx'
# 'Optics in Art and Art Analysis.pptx'
# 'OUR CErtificate.gdoc'
# 'OUR CErtificate.pdf'
# 'output v1_100dpi.png'
# 'output v2_100dpi.png'
# 'output v3_100dpi.png'
# 'output v3_500.png'
# 'output v4_100dpi.png'
# 'output v5_100dpi.png'
# 'output v6_100dpi.png'
# 'OVCRD IPA Reference Slip (2021-0929-1691-5873).pdf'
# 'PA-08 Narag et al.pdf'
#  PA-08.pdf
# 'Parallel Presentation.gslides'
# 'PEER EVALUTION - Physics 72.1 HBC-1 .gform'
# 'PEER EVALUTION - Physics 72.1 TDE-1 .gform'
# 'PEER EVALUTION - Physics 72.1 WDE-1 .gform'
# 'PhD Candidacy Slides.pdf'
# 'PhD Candidacy Slides.pptx'
# 'Physics 107.1 Drive'
# 'Physics 107.1 MBCD-2_studentcontactlist.xlsx'
#  Physics305_plasma
# 'Physics 71.1 WIJ FIJ and 72.1 TBC.gsheet'
#  Physics_71_Syllabus.zip
# 'Physics_71_Syllabus.zip (Unzipped Files)'
# '[Physics 71 V-2] Attendance.gsheet'
# 'Physics 72.1 2nd Sem AY 2019-2020.gsheet'
# 'Rene Jem utang.gsheet'
# 'Research files'
# 'Sablay picture.jpeg'
# 'saved_model (1).pb'
# 'saved_model (2).pb'
# 'saved_model (3).pb'
# 'saved_model (4).pb'
# 'saved_model (5).pb'
# 'saved_model (6).pb'
#  saved_model.pb
# 'Screenshot 2023-02-12 at 12.13.51 (1).png'
# 'Screenshot 2023-02-12 at 12.13.51.png'
# 'Screenshot 2023-06-29 at 19.20.04.png'
# 'Screenshot 2023-06-29 at 19.26.09.png'
#  sd
#  Smokers.mp4
# 'SORRY SIR HUHU.gdoc'
# 'SORRY SIR HUHU.pdf'
# 'SPP-2023-1H-04 (1).pptx'
#  SPP-2023-1H-04.pptx
#  SPP_2023-Contributed-26.pdf
# 'SPP-2023-PB-05  .pdf'
#  SPP_Appearance-45.pdf
# 'SPP Cert of Appearance NARAG (1).pdf'
# 'SPP Cert of Appearance NARAG (2).pdf'
# 'SPP Cert of Appearance NARAG.pdf'
# 'Testing on DIV2K dataset.pdf'
# '[THY-FX] Physics 181 LE1 Submissions 2nd Sem AY 2020-21'
#  Travel-Report-Form-2019.pdf
# 'Undergraduate Research'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet.gsheet'
# '[Updated] Physics 71 THQ-FQ-1_studentcontactlist (1).xlsx'
# '[Updated] Physics 71 THQ-FQ-1_studentcontactlist.xlsx'
# 'variables (1).data-00000-of-00001'
# 'variables (2).data-00000-of-00001'
# 'variables (3).data-00000-of-00001'
# 'variables (4).data-00000-of-00001'
# 'variables (5).data-00000-of-00001'
# 'variables (6).data-00000-of-00001'
#  variables.data-00000-of-00001
# 'Waiver for more than 18 units [2nd sem AY 20-21].gdoc'

# %% [markdown]
# ## Installing packages

# %%
import time
import pandas as pd

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

from PIL import Image, ImageOps
import os
import numpy as np

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from scipy.ndimage import zoom

import cv2
from skimage import color

from tensorflow import keras
from PIL import Image, ImageOps
import numpy as np
import PIL
PIL.Image.MAX_IMAGE_PIXELS = 236958876
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Defining functions

# %%
def zoom_and_resize(img, zoom_factor):
    height, width = img.shape[:2]
    crop_top = int((height - height / zoom_factor) / 2)# Calculate the region to crop around the center
    crop_bottom = int(height - crop_top)
    crop_left = int((width - width / zoom_factor) / 2)
    crop_right = int(width - crop_left)
    cropped_image = img[crop_top:crop_bottom, crop_left:crop_right]    # Crop the image
    resized_image = cv2.resize(cropped_image, (width, height))# Resize the zoomed image back to the original dimensions
    return resized_image

def crop(im):
    width, height = im.size
    data = []
    step = int(size * 0.80)  # Adjust the step size for cropping
    for j in range(0, height, step):
        for i in range(0, width, step):
            if i + size <= width and j + size <= height:
                im1 = im.crop((i, j, i + size, j + size))
                im1 = np.array(im1).astype(np.float32)
                data.append(im1/255)
                #im1 = np.rot90(im1)
                #data.append(im1/255)
                #im1 = np.rot90(im1)
                #data.append(im1/255)
                #im1 = np.rot90(im1)
                #data.append(im1/255)
                for z in zoom_factor:
                    zoomed_img = zoom_and_resize(im1, z)
                    data.append(zoomed_img/255)
    return data

def contrast_stretch(image):
    img_array = np.array(image)
    for i in range(3):  # 3 channels: Red, Green, Blue
        # Compute min and max pixel intensity values for the channel
        min_val = np.min(img_array[:,:,i])
        max_val = np.max(img_array[:,:,i])
        # Apply contrast stretching
        img_array[:,:,i] = (img_array[:,:,i] - min_val) * (255.0 / (max_val - min_val))
    # Convert numpy array back to PIL Image
    stretched_image = Image.fromarray(np.uint8(img_array))
    return stretched_image

# %% [markdown]
# ## Preparing the training dataset

# %%
size = 32
model_number = size

zoom_factor = [1.50, 2.0,2.5]
input = []
output = []

input_folder_path = file_path + 'Training/input/'
output_folder_path = file_path + 'Training/output/'

# List all files in the directory and sort them alphabetically
input_files = sorted(os.listdir(input_folder_path))
output_files = sorted(os.listdir(output_folder_path))


for image_file in input_files:
    image_path = os.path.join(input_folder_path, image_file)
    image = contrast_stretch(Image.open(image_path).convert('RGB'))
    image = crop(image)
    input.extend(image)

for image_file in output_files:
    image_path = os.path.join(output_folder_path, image_file)
    image = Image.open(image_path).convert('RGB')
    image = crop(image)
    output.extend(image)
input = np.array(input)
output = np.array(output)

print("Done reading the input of size = ", input.shape)
print("Done reading the output of size = ", output.shape)

# Split the data into training and testing sets
train_input, test_input, train_output, test_output = train_test_split(
    input, output, test_size=0.2, random_state=42)

print("Done reading the train input of size = ", train_input.shape)
print("Done reading the test input of size = ", test_input.shape)
print("Done reading the train output of size = ", train_input.shape)
print("Done reading the test output of size = ", test_input.shape)

input = []
output = []
# Out:
# Done reading the input of size =  (31832, 32, 32, 3)
# Done reading the output of size =  (31832, 32, 32, 3)
# Done reading the train input of size =  (25465, 32, 32, 3)
# Done reading the test input of size =  (6367, 32, 32, 3)
# Done reading the train output of size =  (25465, 32, 32, 3)
# Done reading the test output of size =  (6367, 32, 32, 3)

# %%
N = 600
n = 10
plt.figure(figsize=(20, 4))
for i in range(0,10):
    ax = plt.subplot(2, n, i + 1)
    plt.title("input")
    plt.imshow((train_input[i+N]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    bx = plt.subplot(2, n, i + n + 1)
    plt.title("output")
    plt.imshow((train_output[i+N]))
    plt.gray()
    bx.get_xaxis().set_visible(False)
    bx.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# ## Creating the Unet model

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization
from keras.optimizers import Adam
import tensorflow as tf

size = 32

# SSIM loss function
def ssim_loss(y_true, y_pred):
    return 1 - tf.reduce_mean(tf.image.ssim(y_true, y_pred, max_val=1.0))

def unet_model(input_shape=(size, size, 3)):
    inputs = Input(input_shape)

    # Contracting Path
    conv1 = Conv2D(8, 3, activation='relu', padding='same')(inputs)
    conv1 = Conv2D(8, 3, activation='relu', padding='same')(conv1)

    conv2 = Conv2D(16, 3, activation='relu', padding='same', strides=2)(conv1)
    conv2 = Conv2D(16, 3, activation='relu', padding='same')(conv2)

    conv3 = Conv2D(32, 3, activation='relu', padding='same', strides=2)(conv2)
    conv3 = Conv2D(32, 3, activation='relu', padding='same')(conv3)

    #conv4 = Conv2D(64, 3, activation='relu', padding='same', strides=2)(conv3)
    #conv4 = Conv2D(64, 3, activation='relu', padding='same')(conv4)

    #conv5 = concatenate([Conv2DTranspose(32, kernel_size=3, strides=2, activation='relu', padding='same')(conv4), conv3], axis=-1)
    #conv5 = Conv2D(32, 3, activation='relu', padding='same')(conv5)

    conv6 = concatenate([Conv2DTranspose(16, kernel_size=3, strides=2, activation='relu', padding='same')(conv3), conv2], axis=-1)
    conv6 = Conv2D(16, 3, activation='relu', padding='same')(conv6)

    conv7 = concatenate([Conv2DTranspose(8, kernel_size=3, strides=2, activation='relu', padding='same')(conv6), conv1], axis=-1)
    conv7 = Conv2D(8, 3, activation='relu', padding='same')(conv7)

    # Output Layer
    output = Conv2D(3, kernel_size=(3, 3), activation='sigmoid', padding='same')(conv7)

    model = Model(inputs=inputs, outputs=output)
    return model

# Usage example:
unet = unet_model()
unet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  conv2d (Conv2D)             (None, 32, 32, 8)            224       ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 8)            584       ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 16)           1168      ['conv2d_1[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 16)           2320      ['conv2d_2[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 32)             4640      ['conv2d_3[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 32)             9248      ['conv2d_4[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 16, 16, 16)           4624      ['conv2d_5[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 16, 16, 32)           0         ['conv2d_transpose[0][0]',
#                                                                      'conv2d_3[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 16)           4624      ['concatenate[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 32, 32, 8)            1160      ['conv2d_6[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 32, 32, 16)           0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 8)            1160      ['concatenate_1[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 3)            219       ['conv2d_7[0][0]']
#
# ==================================================================================================
# Total params: 29971 (117.07 KB)
# Trainable params: 29971 (117.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training the Unet model

# %%
from keras.optimizers import Adam
from tensorflow.keras import layers, losses

opt = Adam(learning_rate=0.0001)
unet.compile(optimizer=opt, loss=ssim_loss)  # Using SSIM loss function
#unet.compile(optimizer=opt, loss=losses.MeanSquaredError())
# Train your model as before
start = time.time()
model = unet.fit(train_input, train_output,
                epochs=500,
                shuffle=True,
                validation_data=(test_input, test_output),batch_size=32)
end = time.time()

print("The time of execution of above program is :",
      (end-start), "seconds")

unet.save(file_path + 'Model/unet_' + str(model_number) + '_rgb')

loss = model.history['loss']
loss = pd.DataFrame(loss)
loss.to_csv(file_path + 'Model/loss_'+ str(model_number) + '_rgb.csv')
val_loss = model.history['val_loss']
val_loss = pd.DataFrame(val_loss)
val_loss.to_csv(file_path  +'Model/val_loss_'+ str(model_number)+ '_rgb.csv')
# Out:
# Epoch 1/500
# 796/796 [==============================] - 17s 11ms/step - loss: 0.2217 - val_loss: 0.1575
# Epoch 2/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1490 - val_loss: 0.1442
# Epoch 3/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1425 - val_loss: 0.1409
# Epoch 4/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1390 - val_loss: 0.1376
# Epoch 5/500
# 796/796 [==============================] - 9s 11ms/step - loss: 0.1363 - val_loss: 0.1360
# Epoch 6/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1343 - val_loss: 0.1336
# Epoch 7/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1327 - val_loss: 0.1321
# Epoch 8/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1313 - val_loss: 0.1310
# Epoch 9/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1303 - val_loss: 0.1320
# Epoch 10/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1293 - val_loss: 0.1292
# Epoch 11/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1284 - val_loss: 0.1283
# Epoch 12/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1276 - val_loss: 0.1277
# Epoch 13/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1270 - val_loss: 0.1279
# Epoch 14/500
# 796/796 [==============================] - 6s 8ms/step - loss: 0.1264 - val_loss: 0.1270
# Epoch 15/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1260 - val_loss: 0.1257
# Epoch 16/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1253 - val_loss: 0.1253
# Epoch 17/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1249 - val_loss: 0.1250
# Epoch 18/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1244 - val_loss: 0.1248
# Epoch 19/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1238 - val_loss: 0.1247
# Epoch 20/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1233 - val_loss: 0.1240
# Epoch 21/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1230 - val_loss: 0.1230
# Epoch 22/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1227 - val_loss: 0.1232
# Epoch 23/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1223 - val_loss: 0.1228
# Epoch 24/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1218 - val_loss: 0.1228
# Epoch 25/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1215 - val_loss: 0.1223
# Epoch 26/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1212 - val_loss: 0.1226
# Epoch 27/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1207 - val_loss: 0.1212
# Epoch 28/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1204 - val_loss: 0.1213
# Epoch 29/500
# 796/796 [==============================] - 6s 8ms/step - loss: 0.1201 - val_loss: 0.1206
# Epoch 30/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1199 - val_loss: 0.1219
# Epoch 31/500
# 796/796 [==============================] - 9s 11ms/step - loss: 0.1194 - val_loss: 0.1196
# Epoch 32/500
# 796/796 [==============================] - 11s 14ms/step - loss: 0.1190 - val_loss: 0.1196
# Epoch 33/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1188 - val_loss: 0.1204
# Epoch 34/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1185 - val_loss: 0.1191
# Epoch 35/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1183 - val_loss: 0.1189
# Epoch 36/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1180 - val_loss: 0.1187
# Epoch 37/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1177 - val_loss: 0.1188
# Epoch 38/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1175 - val_loss: 0.1181
# Epoch 39/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1174 - val_loss: 0.1179
# Epoch 40/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1170 - val_loss: 0.1189
# Epoch 41/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1168 - val_loss: 0.1175
# Epoch 42/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1166 - val_loss: 0.1181
# Epoch 43/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1166 - val_loss: 0.1173
# Epoch 44/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1163 - val_loss: 0.1175
# Epoch 45/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1161 - val_loss: 0.1173
# Epoch 46/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1159 - val_loss: 0.1173
# Epoch 47/500
# 796/796 [==============================] - 8s 11ms/step - loss: 0.1158 - val_loss: 0.1173
# Epoch 48/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1156 - val_loss: 0.1167
# Epoch 49/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1154 - val_loss: 0.1166
# Epoch 50/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1153 - val_loss: 0.1165
# Epoch 51/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1152 - val_loss: 0.1171
# Epoch 52/500
# 796/796 [==============================] - 6s 8ms/step - loss: 0.1149 - val_loss: 0.1161
# Epoch 53/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1149 - val_loss: 0.1159
# Epoch 54/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1146 - val_loss: 0.1162
# Epoch 55/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1146 - val_loss: 0.1155
# Epoch 56/500
# 796/796 [==============================] - 6s 8ms/step - loss: 0.1145 - val_loss: 0.1166
# Epoch 57/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1142 - val_loss: 0.1156
# Epoch 58/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1140 - val_loss: 0.1153
# Epoch 59/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1140 - val_loss: 0.1161
# Epoch 60/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1139 - val_loss: 0.1152
# Epoch 61/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1137 - val_loss: 0.1154
# Epoch 62/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1136 - val_loss: 0.1160
# Epoch 63/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1136 - val_loss: 0.1155
# Epoch 64/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1132 - val_loss: 0.1152
# Epoch 65/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1133 - val_loss: 0.1145
# Epoch 66/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1131 - val_loss: 0.1148
# Epoch 67/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1130 - val_loss: 0.1147
# Epoch 68/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1129 - val_loss: 0.1149
# Epoch 69/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1127 - val_loss: 0.1140
# Epoch 70/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1126 - val_loss: 0.1138
# Epoch 71/500
# 796/796 [==============================] - 6s 8ms/step - loss: 0.1124 - val_loss: 0.1150
# Epoch 72/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1124 - val_loss: 0.1135
# Epoch 73/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1123 - val_loss: 0.1140
# Epoch 74/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1121 - val_loss: 0.1136
# Epoch 75/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1122 - val_loss: 0.1146
# Epoch 76/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1121 - val_loss: 0.1134
# Epoch 77/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1118 - val_loss: 0.1129
# Epoch 78/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1117 - val_loss: 0.1131
# Epoch 79/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1117 - val_loss: 0.1129
# Epoch 80/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1115 - val_loss: 0.1125
# Epoch 81/500
# 796/796 [==============================] - 6s 8ms/step - loss: 0.1114 - val_loss: 0.1130
# Epoch 82/500
# 796/796 [==============================] - 8s 11ms/step - loss: 0.1112 - val_loss: 0.1130
# Epoch 83/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1113 - val_loss: 0.1126
# Epoch 84/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1111 - val_loss: 0.1121
# Epoch 85/500
# 796/796 [==============================] - 6s 8ms/step - loss: 0.1109 - val_loss: 0.1123
# Epoch 86/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1110 - val_loss: 0.1125
# Epoch 87/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1107 - val_loss: 0.1116
# Epoch 88/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1108 - val_loss: 0.1122
# Epoch 89/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1107 - val_loss: 0.1117
# Epoch 90/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1106 - val_loss: 0.1132
# Epoch 91/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1105 - val_loss: 0.1121
# Epoch 92/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1104 - val_loss: 0.1119
# Epoch 93/500
# 796/796 [==============================] - 8s 9ms/step - loss: 0.1103 - val_loss: 0.1129
# Epoch 94/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1104 - val_loss: 0.1130
# Epoch 95/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1101 - val_loss: 0.1116
# Epoch 96/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1101 - val_loss: 0.1112
# Epoch 97/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1101 - val_loss: 0.1122
# Epoch 98/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1100 - val_loss: 0.1116
# Epoch 99/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1098 - val_loss: 0.1119
# Epoch 100/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1098 - val_loss: 0.1109
# Epoch 101/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1096 - val_loss: 0.1108
# Epoch 102/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1095 - val_loss: 0.1110
# Epoch 103/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1096 - val_loss: 0.1118
# Epoch 104/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1094 - val_loss: 0.1118
# Epoch 105/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1093 - val_loss: 0.1135
# Epoch 106/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1094 - val_loss: 0.1108
# Epoch 107/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1093 - val_loss: 0.1104
# Epoch 108/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1093 - val_loss: 0.1110
# Epoch 109/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1091 - val_loss: 0.1106
# Epoch 110/500
# 796/796 [==============================] - 6s 8ms/step - loss: 0.1090 - val_loss: 0.1104
# Epoch 111/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1090 - val_loss: 0.1107
# Epoch 112/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1090 - val_loss: 0.1108
# Epoch 113/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1088 - val_loss: 0.1103
# Epoch 114/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1087 - val_loss: 0.1114
# Epoch 115/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1087 - val_loss: 0.1107
# Epoch 116/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1087 - val_loss: 0.1100
# Epoch 117/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1087 - val_loss: 0.1102
# Epoch 118/500
# 796/796 [==============================] - 6s 8ms/step - loss: 0.1086 - val_loss: 0.1100
# Epoch 119/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1085 - val_loss: 0.1101
# Epoch 120/500
# 796/796 [==============================] - 6s 8ms/step - loss: 0.1085 - val_loss: 0.1117
# Epoch 121/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1085 - val_loss: 0.1098
# Epoch 122/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1083 - val_loss: 0.1095
# Epoch 123/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1084 - val_loss: 0.1093
# Epoch 124/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1081 - val_loss: 0.1096
# Epoch 125/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1082 - val_loss: 0.1096
# Epoch 126/500
# 796/796 [==============================] - 6s 8ms/step - loss: 0.1081 - val_loss: 0.1110
# Epoch 127/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1080 - val_loss: 0.1107
# Epoch 128/500
# 796/796 [==============================] - 6s 8ms/step - loss: 0.1079 - val_loss: 0.1101
# Epoch 129/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1079 - val_loss: 0.1097
# Epoch 130/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1078 - val_loss: 0.1098
# Epoch 131/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1079 - val_loss: 0.1092
# Epoch 132/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1077 - val_loss: 0.1098
# Epoch 133/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1076 - val_loss: 0.1101
# Epoch 134/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1077 - val_loss: 0.1089
# Epoch 135/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1074 - val_loss: 0.1092
# Epoch 136/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1076 - val_loss: 0.1095
# Epoch 137/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1074 - val_loss: 0.1100
# Epoch 138/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1074 - val_loss: 0.1097
# Epoch 139/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1072 - val_loss: 0.1089
# Epoch 140/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1075 - val_loss: 0.1098
# Epoch 141/500
# 796/796 [==============================] - 8s 9ms/step - loss: 0.1074 - val_loss: 0.1097
# Epoch 142/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1073 - val_loss: 0.1094
# Epoch 143/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1072 - val_loss: 0.1092
# Epoch 144/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1071 - val_loss: 0.1097
# Epoch 145/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1070 - val_loss: 0.1091
# Epoch 146/500
# 796/796 [==============================] - 8s 9ms/step - loss: 0.1071 - val_loss: 0.1088
# Epoch 147/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1071 - val_loss: 0.1100
# Epoch 148/500
# 796/796 [==============================] - 8s 9ms/step - loss: 0.1069 - val_loss: 0.1096
# Epoch 149/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1070 - val_loss: 0.1090
# Epoch 150/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1069 - val_loss: 0.1082
# Epoch 151/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1068 - val_loss: 0.1087
# Epoch 152/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1068 - val_loss: 0.1092
# Epoch 153/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1068 - val_loss: 0.1085
# Epoch 154/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1067 - val_loss: 0.1097
# Epoch 155/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1066 - val_loss: 0.1088
# Epoch 156/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1067 - val_loss: 0.1087
# Epoch 157/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1065 - val_loss: 0.1083
# Epoch 158/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1065 - val_loss: 0.1086
# Epoch 159/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1065 - val_loss: 0.1086
# Epoch 160/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1065 - val_loss: 0.1102
# Epoch 161/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1063 - val_loss: 0.1085
# Epoch 162/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1065 - val_loss: 0.1092
# Epoch 163/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1062 - val_loss: 0.1079
# Epoch 164/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1062 - val_loss: 0.1080
# Epoch 165/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1061 - val_loss: 0.1097
# Epoch 166/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1061 - val_loss: 0.1100
# Epoch 167/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1062 - val_loss: 0.1086
# Epoch 168/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1061 - val_loss: 0.1084
# Epoch 169/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1060 - val_loss: 0.1082
# Epoch 170/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1060 - val_loss: 0.1091
# Epoch 171/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1060 - val_loss: 0.1076
# Epoch 172/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1060 - val_loss: 0.1080
# Epoch 173/500
# 796/796 [==============================] - 8s 9ms/step - loss: 0.1059 - val_loss: 0.1076
# Epoch 174/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1058 - val_loss: 0.1083
# Epoch 175/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1058 - val_loss: 0.1080
# Epoch 176/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1058 - val_loss: 0.1084
# Epoch 177/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1056 - val_loss: 0.1077
# Epoch 178/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1057 - val_loss: 0.1077
# Epoch 179/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1055 - val_loss: 0.1078
# Epoch 180/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1056 - val_loss: 0.1072
# Epoch 181/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1056 - val_loss: 0.1077
# Epoch 182/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1055 - val_loss: 0.1078
# Epoch 183/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1055 - val_loss: 0.1074
# Epoch 184/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1054 - val_loss: 0.1078
# Epoch 185/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1054 - val_loss: 0.1075
# Epoch 186/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1054 - val_loss: 0.1085
# Epoch 187/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1053 - val_loss: 0.1084
# Epoch 188/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1054 - val_loss: 0.1081
# Epoch 189/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1053 - val_loss: 0.1072
# Epoch 190/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1052 - val_loss: 0.1075
# Epoch 191/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1052 - val_loss: 0.1074
# Epoch 192/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1051 - val_loss: 0.1075
# Epoch 193/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1051 - val_loss: 0.1079
# Epoch 194/500
# 796/796 [==============================] - 6s 8ms/step - loss: 0.1051 - val_loss: 0.1069
# Epoch 195/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1051 - val_loss: 0.1070
# Epoch 196/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1051 - val_loss: 0.1074
# Epoch 197/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1050 - val_loss: 0.1071
# Epoch 198/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1049 - val_loss: 0.1069
# Epoch 199/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1050 - val_loss: 0.1066
# Epoch 200/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1050 - val_loss: 0.1071
# Epoch 201/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1049 - val_loss: 0.1075
# Epoch 202/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1048 - val_loss: 0.1074
# Epoch 203/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1048 - val_loss: 0.1082
# Epoch 204/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1048 - val_loss: 0.1072
# Epoch 205/500
# 796/796 [==============================] - 8s 9ms/step - loss: 0.1047 - val_loss: 0.1076
# Epoch 206/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1049 - val_loss: 0.1069
# Epoch 207/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1047 - val_loss: 0.1094
# Epoch 208/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1047 - val_loss: 0.1088
# Epoch 209/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1047 - val_loss: 0.1073
# Epoch 210/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1047 - val_loss: 0.1078
# Epoch 211/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1046 - val_loss: 0.1068
# Epoch 212/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1045 - val_loss: 0.1075
# Epoch 213/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1044 - val_loss: 0.1069
# Epoch 214/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1045 - val_loss: 0.1065
# Epoch 215/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1044 - val_loss: 0.1069
# Epoch 216/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1045 - val_loss: 0.1066
# Epoch 217/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1043 - val_loss: 0.1072
# Epoch 218/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1043 - val_loss: 0.1080
# Epoch 219/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1044 - val_loss: 0.1072
# Epoch 220/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1045 - val_loss: 0.1074
# Epoch 221/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1043 - val_loss: 0.1086
# Epoch 222/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1041 - val_loss: 0.1065
# Epoch 223/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1041 - val_loss: 0.1065
# Epoch 224/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1040 - val_loss: 0.1069
# Epoch 225/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1042 - val_loss: 0.1073
# Epoch 226/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1041 - val_loss: 0.1069
# Epoch 227/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1041 - val_loss: 0.1067
# Epoch 228/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1041 - val_loss: 0.1074
# Epoch 229/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1040 - val_loss: 0.1066
# Epoch 230/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1040 - val_loss: 0.1071
# Epoch 231/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1039 - val_loss: 0.1060
# Epoch 232/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1041 - val_loss: 0.1071
# Epoch 233/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1040 - val_loss: 0.1063
# Epoch 234/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1038 - val_loss: 0.1097
# Epoch 235/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1040 - val_loss: 0.1062
# Epoch 236/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1040 - val_loss: 0.1073
# Epoch 237/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1037 - val_loss: 0.1076
# Epoch 238/500
# 796/796 [==============================] - 8s 9ms/step - loss: 0.1040 - val_loss: 0.1066
# Epoch 239/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1038 - val_loss: 0.1068
# Epoch 240/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1037 - val_loss: 0.1064
# Epoch 241/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1037 - val_loss: 0.1067
# Epoch 242/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1038 - val_loss: 0.1061
# Epoch 243/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1038 - val_loss: 0.1080
# Epoch 244/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1036 - val_loss: 0.1062
# Epoch 245/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1037 - val_loss: 0.1065
# Epoch 246/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1037 - val_loss: 0.1064
# Epoch 247/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1036 - val_loss: 0.1069
# Epoch 248/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1035 - val_loss: 0.1090
# Epoch 249/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1035 - val_loss: 0.1065
# Epoch 250/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1035 - val_loss: 0.1075
# Epoch 251/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1036 - val_loss: 0.1061
# Epoch 252/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1034 - val_loss: 0.1060
# Epoch 253/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1034 - val_loss: 0.1064
# Epoch 254/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1036 - val_loss: 0.1063
# Epoch 255/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1034 - val_loss: 0.1076
# Epoch 256/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1033 - val_loss: 0.1083
# Epoch 257/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1033 - val_loss: 0.1080
# Epoch 258/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1033 - val_loss: 0.1063
# Epoch 259/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1033 - val_loss: 0.1056
# Epoch 260/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1032 - val_loss: 0.1057
# Epoch 261/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1032 - val_loss: 0.1066
# Epoch 262/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1032 - val_loss: 0.1061
# Epoch 263/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1033 - val_loss: 0.1064
# Epoch 264/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1033 - val_loss: 0.1062
# Epoch 265/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1032 - val_loss: 0.1059
# Epoch 266/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1031 - val_loss: 0.1064
# Epoch 267/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1030 - val_loss: 0.1059
# Epoch 268/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1031 - val_loss: 0.1063
# Epoch 269/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1031 - val_loss: 0.1065
# Epoch 270/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1031 - val_loss: 0.1072
# Epoch 271/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1029 - val_loss: 0.1054
# Epoch 272/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1030 - val_loss: 0.1055
# Epoch 273/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1030 - val_loss: 0.1057
# Epoch 274/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1029 - val_loss: 0.1065
# Epoch 275/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1030 - val_loss: 0.1057
# Epoch 276/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1028 - val_loss: 0.1063
# Epoch 277/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1028 - val_loss: 0.1057
# Epoch 278/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1029 - val_loss: 0.1055
# Epoch 279/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1028 - val_loss: 0.1059
# Epoch 280/500
# 796/796 [==============================] - 8s 9ms/step - loss: 0.1028 - val_loss: 0.1075
# Epoch 281/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1029 - val_loss: 0.1072
# Epoch 282/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1028 - val_loss: 0.1073
# Epoch 283/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1027 - val_loss: 0.1054
# Epoch 284/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1026 - val_loss: 0.1068
# Epoch 285/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1028 - val_loss: 0.1062
# Epoch 286/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1028 - val_loss: 0.1060
# Epoch 287/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1026 - val_loss: 0.1054
# Epoch 288/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1027 - val_loss: 0.1057
# Epoch 289/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1027 - val_loss: 0.1061
# Epoch 290/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1026 - val_loss: 0.1062
# Epoch 291/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1025 - val_loss: 0.1052
# Epoch 292/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1025 - val_loss: 0.1054
# Epoch 293/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1025 - val_loss: 0.1063
# Epoch 294/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1026 - val_loss: 0.1058
# Epoch 295/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1025 - val_loss: 0.1056
# Epoch 296/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1027 - val_loss: 0.1054
# Epoch 297/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1026 - val_loss: 0.1072
# Epoch 298/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1025 - val_loss: 0.1056
# Epoch 299/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1026 - val_loss: 0.1053
# Epoch 300/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1024 - val_loss: 0.1055
# Epoch 301/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1023 - val_loss: 0.1059
# Epoch 302/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1024 - val_loss: 0.1058
# Epoch 303/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1024 - val_loss: 0.1056
# Epoch 304/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1024 - val_loss: 0.1063
# Epoch 305/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1023 - val_loss: 0.1061
# Epoch 306/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1023 - val_loss: 0.1054
# Epoch 307/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1023 - val_loss: 0.1055
# Epoch 308/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1023 - val_loss: 0.1056
# Epoch 309/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1023 - val_loss: 0.1055
# Epoch 310/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1023 - val_loss: 0.1052
# Epoch 311/500
# 796/796 [==============================] - 8s 9ms/step - loss: 0.1023 - val_loss: 0.1053
# Epoch 312/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1023 - val_loss: 0.1054
# Epoch 313/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1023 - val_loss: 0.1057
# Epoch 314/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1022 - val_loss: 0.1054
# Epoch 315/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1024 - val_loss: 0.1072
# Epoch 316/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1021 - val_loss: 0.1065
# Epoch 317/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1020 - val_loss: 0.1057
# Epoch 318/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1021 - val_loss: 0.1057
# Epoch 319/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1022 - val_loss: 0.1051
# Epoch 320/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1021 - val_loss: 0.1055
# Epoch 321/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1019 - val_loss: 0.1049
# Epoch 322/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1021 - val_loss: 0.1051
# Epoch 323/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1020 - val_loss: 0.1055
# Epoch 324/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1021 - val_loss: 0.1057
# Epoch 325/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1019 - val_loss: 0.1058
# Epoch 326/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1020 - val_loss: 0.1060
# Epoch 327/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1019 - val_loss: 0.1060
# Epoch 328/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1019 - val_loss: 0.1056
# Epoch 329/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1018 - val_loss: 0.1047
# Epoch 330/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1020 - val_loss: 0.1055
# Epoch 331/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1019 - val_loss: 0.1055
# Epoch 332/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1019 - val_loss: 0.1062
# Epoch 333/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1018 - val_loss: 0.1054
# Epoch 334/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1018 - val_loss: 0.1054
# Epoch 335/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1019 - val_loss: 0.1051
# Epoch 336/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1018 - val_loss: 0.1052
# Epoch 337/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1018 - val_loss: 0.1055
# Epoch 338/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1017 - val_loss: 0.1052
# Epoch 339/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1018 - val_loss: 0.1052
# Epoch 340/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1017 - val_loss: 0.1052
# Epoch 341/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1017 - val_loss: 0.1051
# Epoch 342/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1017 - val_loss: 0.1054
# Epoch 343/500
# 796/796 [==============================] - 8s 9ms/step - loss: 0.1017 - val_loss: 0.1060
# Epoch 344/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1017 - val_loss: 0.1068
# Epoch 345/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1016 - val_loss: 0.1049
# Epoch 346/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1015 - val_loss: 0.1059
# Epoch 347/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1016 - val_loss: 0.1063
# Epoch 348/500
# 796/796 [==============================] - 8s 11ms/step - loss: 0.1020 - val_loss: 0.1061
# Epoch 349/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1016 - val_loss: 0.1049
# Epoch 350/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1016 - val_loss: 0.1051
# Epoch 351/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1015 - val_loss: 0.1055
# Epoch 352/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1015 - val_loss: 0.1045
# Epoch 353/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1015 - val_loss: 0.1052
# Epoch 354/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1015 - val_loss: 0.1046
# Epoch 355/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1016 - val_loss: 0.1048
# Epoch 356/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1015 - val_loss: 0.1050
# Epoch 357/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1015 - val_loss: 0.1050
# Epoch 358/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1015 - val_loss: 0.1057
# Epoch 359/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1015 - val_loss: 0.1056
# Epoch 360/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1013 - val_loss: 0.1049
# Epoch 361/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1014 - val_loss: 0.1044
# Epoch 362/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1015 - val_loss: 0.1053
# Epoch 363/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1014 - val_loss: 0.1046
# Epoch 364/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1014 - val_loss: 0.1059
# Epoch 365/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1013 - val_loss: 0.1047
# Epoch 366/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1015 - val_loss: 0.1066
# Epoch 367/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1015 - val_loss: 0.1054
# Epoch 368/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1013 - val_loss: 0.1056
# Epoch 369/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1012 - val_loss: 0.1046
# Epoch 370/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1013 - val_loss: 0.1058
# Epoch 371/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1013 - val_loss: 0.1046
# Epoch 372/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1014 - val_loss: 0.1048
# Epoch 373/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1011 - val_loss: 0.1049
# Epoch 374/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1013 - val_loss: 0.1049
# Epoch 375/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1012 - val_loss: 0.1052
# Epoch 376/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1013 - val_loss: 0.1061
# Epoch 377/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1013 - val_loss: 0.1045
# Epoch 378/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1013 - val_loss: 0.1045
# Epoch 379/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1012 - val_loss: 0.1048
# Epoch 380/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1012 - val_loss: 0.1051
# Epoch 381/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1011 - val_loss: 0.1047
# Epoch 382/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1011 - val_loss: 0.1050
# Epoch 383/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1011 - val_loss: 0.1050
# Epoch 384/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1012 - val_loss: 0.1053
# Epoch 385/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1010 - val_loss: 0.1049
# Epoch 386/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1010 - val_loss: 0.1043
# Epoch 387/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1011 - val_loss: 0.1046
# Epoch 388/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1011 - val_loss: 0.1046
# Epoch 389/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1011 - val_loss: 0.1046
# Epoch 390/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1010 - val_loss: 0.1050
# Epoch 391/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1010 - val_loss: 0.1049
# Epoch 392/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1011 - val_loss: 0.1047
# Epoch 393/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1010 - val_loss: 0.1044
# Epoch 394/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1010 - val_loss: 0.1048
# Epoch 395/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1010 - val_loss: 0.1055
# Epoch 396/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1009 - val_loss: 0.1046
# Epoch 397/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1010 - val_loss: 0.1049
# Epoch 398/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1009 - val_loss: 0.1046
# Epoch 399/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1010 - val_loss: 0.1050
# Epoch 400/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1009 - val_loss: 0.1044
# Epoch 401/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1009 - val_loss: 0.1043
# Epoch 402/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1009 - val_loss: 0.1058
# Epoch 403/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1010 - val_loss: 0.1046
# Epoch 404/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1009 - val_loss: 0.1048
# Epoch 405/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1009 - val_loss: 0.1052
# Epoch 406/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1008 - val_loss: 0.1048
# Epoch 407/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1008 - val_loss: 0.1050
# Epoch 408/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1009 - val_loss: 0.1044
# Epoch 409/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1008 - val_loss: 0.1047
# Epoch 410/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1008 - val_loss: 0.1048
# Epoch 411/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1007 - val_loss: 0.1048
# Epoch 412/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1009 - val_loss: 0.1044
# Epoch 413/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1007 - val_loss: 0.1046
# Epoch 414/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1008 - val_loss: 0.1047
# Epoch 415/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1007 - val_loss: 0.1044
# Epoch 416/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1006 - val_loss: 0.1051
# Epoch 417/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1007 - val_loss: 0.1042
# Epoch 418/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1007 - val_loss: 0.1047
# Epoch 419/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1005 - val_loss: 0.1045
# Epoch 420/500
# 796/796 [==============================] - 8s 9ms/step - loss: 0.1007 - val_loss: 0.1054
# Epoch 421/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1005 - val_loss: 0.1044
# Epoch 422/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1007 - val_loss: 0.1045
# Epoch 423/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1007 - val_loss: 0.1044
# Epoch 424/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1005 - val_loss: 0.1050
# Epoch 425/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1007 - val_loss: 0.1051
# Epoch 426/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1006 - val_loss: 0.1043
# Epoch 427/500
# 796/796 [==============================] - 9s 11ms/step - loss: 0.1005 - val_loss: 0.1052
# Epoch 428/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1006 - val_loss: 0.1047
# Epoch 429/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1004 - val_loss: 0.1044
# Epoch 430/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1005 - val_loss: 0.1041
# Epoch 431/500
# 796/796 [==============================] - 8s 11ms/step - loss: 0.1004 - val_loss: 0.1046
# Epoch 432/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1005 - val_loss: 0.1060
# Epoch 433/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1005 - val_loss: 0.1047
# Epoch 434/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1005 - val_loss: 0.1050
# Epoch 435/500
# 796/796 [==============================] - 8s 11ms/step - loss: 0.1004 - val_loss: 0.1053
# Epoch 436/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1004 - val_loss: 0.1046
# Epoch 437/500
# 796/796 [==============================] - 8s 11ms/step - loss: 0.1005 - val_loss: 0.1041
# Epoch 438/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1004 - val_loss: 0.1046
# Epoch 439/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1004 - val_loss: 0.1040
# Epoch 440/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1004 - val_loss: 0.1046
# Epoch 441/500
# 796/796 [==============================] - 8s 9ms/step - loss: 0.1004 - val_loss: 0.1041
# Epoch 442/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1003 - val_loss: 0.1051
# Epoch 443/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1002 - val_loss: 0.1058
# Epoch 444/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1004 - val_loss: 0.1043
# Epoch 445/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1003 - val_loss: 0.1048
# Epoch 446/500
# 796/796 [==============================] - 9s 11ms/step - loss: 0.1002 - val_loss: 0.1042
# Epoch 447/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1003 - val_loss: 0.1041
# Epoch 448/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1003 - val_loss: 0.1040
# Epoch 449/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1004 - val_loss: 0.1040
# Epoch 450/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1003 - val_loss: 0.1044
# Epoch 451/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1003 - val_loss: 0.1049
# Epoch 452/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1001 - val_loss: 0.1052
# Epoch 453/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1003 - val_loss: 0.1043
# Epoch 454/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1002 - val_loss: 0.1044
# Epoch 455/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1002 - val_loss: 0.1051
# Epoch 456/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1002 - val_loss: 0.1045
# Epoch 457/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1003 - val_loss: 0.1043
# Epoch 458/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1002 - val_loss: 0.1040
# Epoch 459/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1003 - val_loss: 0.1038
# Epoch 460/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1001 - val_loss: 0.1037
# Epoch 461/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.1001 - val_loss: 0.1061
# Epoch 462/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1001 - val_loss: 0.1040
# Epoch 463/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1001 - val_loss: 0.1040
# Epoch 464/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1001 - val_loss: 0.1043
# Epoch 465/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1000 - val_loss: 0.1045
# Epoch 466/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1001 - val_loss: 0.1041
# Epoch 467/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1001 - val_loss: 0.1044
# Epoch 468/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1000 - val_loss: 0.1049
# Epoch 469/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1001 - val_loss: 0.1039
# Epoch 470/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1002 - val_loss: 0.1040
# Epoch 471/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1001 - val_loss: 0.1067
# Epoch 472/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1001 - val_loss: 0.1043
# Epoch 473/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1000 - val_loss: 0.1049
# Epoch 474/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.1001 - val_loss: 0.1053
# Epoch 475/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1001 - val_loss: 0.1042
# Epoch 476/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.0999 - val_loss: 0.1048
# Epoch 477/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.0999 - val_loss: 0.1039
# Epoch 478/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.0999 - val_loss: 0.1040
# Epoch 479/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1000 - val_loss: 0.1039
# Epoch 480/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.0999 - val_loss: 0.1054
# Epoch 481/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.1000 - val_loss: 0.1038
# Epoch 482/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.0999 - val_loss: 0.1039
# Epoch 483/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.0998 - val_loss: 0.1048
# Epoch 484/500
# 796/796 [==============================] - 7s 8ms/step - loss: 0.0999 - val_loss: 0.1050
# Epoch 485/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.0998 - val_loss: 0.1050
# Epoch 486/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.0999 - val_loss: 0.1042
# Epoch 487/500
# 796/796 [==============================] - 8s 11ms/step - loss: 0.0998 - val_loss: 0.1048
# Epoch 488/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.0998 - val_loss: 0.1039
# Epoch 489/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.0998 - val_loss: 0.1045
# Epoch 490/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.0999 - val_loss: 0.1038
# Epoch 491/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.0999 - val_loss: 0.1055
# Epoch 492/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.0998 - val_loss: 0.1044
# Epoch 493/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.0999 - val_loss: 0.1044
# Epoch 494/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.0997 - val_loss: 0.1036
# Epoch 495/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.0999 - val_loss: 0.1047
# Epoch 496/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.0998 - val_loss: 0.1048
# Epoch 497/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.0998 - val_loss: 0.1036
# Epoch 498/500
# 796/796 [==============================] - 8s 9ms/step - loss: 0.0997 - val_loss: 0.1044
# Epoch 499/500
# 796/796 [==============================] - 7s 9ms/step - loss: 0.0998 - val_loss: 0.1042
# Epoch 500/500
# 796/796 [==============================] - 8s 10ms/step - loss: 0.0996 - val_loss: 0.1040
# The time of execution of above program is : 3747.782552242279 seconds

# %% [markdown]
# ## Testing the model

# %%
n_size = 32
size = 32

def rgb_L_ab(rgb_image, test_L):
    lab_array = color.rgb2lab(np.array(rgb_image))# Convert RGB to LAB colorspace
    lab_array[..., 0] = test_L #Change L channel to input
    rgb_array = color.lab2rgb(lab_array)# Convert back LAB to RGB colorspace
    rgb_array = (rgb_array * 255).astype(np.uint8)# Scale RGB values back to the range [0, 255]
    rgb_array = Image.fromarray(rgb_array, mode='RGB')# Convert RGB array back to image
    return rgb_array

def crop_(im):
    width, height = im.size
    data = []
    for j in range(0,int(height/n_size)):
        for i in range(0,int(width/n_size)):
            im1 = im.crop((0 + (n_size*i), 0 + (n_size*j), n_size + (n_size*i), n_size + (n_size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            data.append(im1)
    return data

#----------------READING THE TEST IMAGE--------------------#
filename = str("TEST_INPUT_[05] Comprimise-d.png")
test = contrast_stretch(Image.open(file_path+ "Testing/" + filename).convert('RGB'))
test_L = color.rgb2lab(np.array(test))
test_L = test_L[..., 0]
w_dirty, h_dirty = test.size
#----------------------------------------------------------#

autoencoder = keras.models.load_model(file_path + 'Model/unet_'+str(n_size)+'_rgb', custom_objects={'ssim_loss': ssim_loss})

xx = int(w_dirty/n_size)
final=[]

for portion in range(0,xx):
    im1 = test.crop((n_size*portion, 0, (n_size*portion) + n_size, h_dirty))
    w1, h1 = im1.size
    w = int(w1/n_size)
    h = int(h1/n_size)
    neverbeforeseen = np.array(crop_(im1))
    decoded_imgs = autoencoder.predict(neverbeforeseen)
    col = np.vstack((decoded_imgs[0],decoded_imgs[1]))
    for i in range(2,h):
        col = np.vstack((col,decoded_imgs[i]))
    y = col
    y = (y * 255).astype('uint8')
    if portion == 0:
        final = y
    if portion > 0:
        final = np.hstack((final,y))

#----------------TEST ON FULL RGB--------------------#
final_rgb = final
final_rgb = np.squeeze(final_rgb)
reconstructed_rgb = Image.fromarray(final_rgb)
reconstructed_rgb.save(file_path + "Testing/"+"Model_1_"+filename)
plt.figure(), plt.imshow(reconstructed_rgb)

#----------------TEST ON L from input and AB from convert RGB2LAB of model--------------------#
final_lab = rgb_L_ab(final, test_L)
final_lab = np.squeeze(final_lab)
reconstructed_lab = Image.fromarray(final_lab)
reconstructed_lab.save(file_path + "Testing/"+"Model_2_"+filename)
plt.figure(), plt.imshow(reconstructed_lab)
# Out:
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 60ms/step
# (<Figure size 640x480 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x7ba5502e7fd0>)

# %%
from PIL import Image
import numpy as np
from skimage.metrics import structural_similarity as ssim

# Function to open image and convert to numpy array
def load_image(image_path):
    image = Image.open(image_path).convert('RGB')  # Ensure image is in RGB mode
    return np.array(image)

image_path1 = file_path + 'Testing/TEST_OUTPUT_[05] Comprimise-d.png'
image_path2 = file_path + "Testing/"+"Model_2_"+filename

# Load images
image1 = load_image(image_path1)
image2 = load_image(image_path2)

# Ensure the images have the same dimensions
if image1.shape != image2.shape:
    raise ValueError("Input images must have the same dimensions.")

# Compute SSIM for each channel and average the results
ssim_index_r = ssim(image1[:, :, 0], image2[:, :, 0], data_range=image1[:, :, 0].max() - image1[:, :, 0].min())
ssim_index_g = ssim(image1[:, :, 1], image2[:, :, 1], data_range=image1[:, :, 1].max() - image1[:, :, 1].min())
ssim_index_b = ssim(image1[:, :, 2], image2[:, :, 2], data_range=image1[:, :, 2].max() - image1[:, :, 2].min())

ssim_index_rgb = (ssim_index_r + ssim_index_g + ssim_index_b) / 3

print(f"SSIM for R channel: {ssim_index_r}")
print(f"SSIM for G channel: {ssim_index_g}")
print(f"SSIM for B channel: {ssim_index_b}")
print(f"Average SSIM for RGB image(Method4): {ssim_index_rgb}")
# Out:
# SSIM for R channel: 0.7149119616494869
# SSIM for G channel: 0.7248725980217174
# SSIM for B channel: 0.7075906602808648
# Average SSIM for RGB image(Method4): 0.7157917399840231
