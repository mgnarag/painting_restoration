# %% [markdown]
# <a href="https://colab.research.google.com/github/mgnarag/painting_restoration/blob/main/Method_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !ls drive/My\ Drive
file_path = "/content/drive/MyDrive/Baumgartner screenshots/"

# %%
import time
import pandas as pd


import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf


from PIL import Image, ImageOps
import os
import numpy as np

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from scipy.ndimage import zoom

import cv2
from skimage import color

epoch = 100
model_number = 128
size = 128


# Generate augmented images with specific rotations
#zoom_factor = [x/5 for x in range(6, 8)]
zoom_factor = [1.50,2.0, 2.50, 3.0, 3.5,4.0]


def zoom_and_resize(img, zoom_factor):
    height, width = img.shape[:2]

    # Calculate the region to crop around the center
    crop_top = int((height - height / zoom_factor) / 2)
    crop_bottom = int(height - crop_top)
    crop_left = int((width - width / zoom_factor) / 2)
    crop_right = int(width - crop_left)
    # Crop the image
    cropped_image = img[crop_top:crop_bottom, crop_left:crop_right]
    # Resize the zoomed image back to the original dimensions
    resized_image = cv2.resize(cropped_image, (width, height))

    return resized_image

def crop(im):
    width, height = im.size
    data = []
    step = int(size * 0.5)  # Adjust the step size for cropping

    for j in range(0, height, step):
        for i in range(0, width, step):
            if i + size <= width and j + size <= height:
                im1 = im.crop((i, j, i + size, j + size))
                im1 = np.array(im1).astype(np.float32)
                data.append(im1/255)
                im1 = np.rot90(im1)
                data.append(im1/255)
                im1 = np.rot90(im1)
                data.append(im1/255)
                im1 = np.rot90(im1)
                data.append(im1/255)
                for z in zoom_factor:
                    zoomed_img = zoom_and_resize(im1, z)
                    data.append(zoomed_img/255)
            #flip_im1 = np.fliplr(im1)

    return data

def rgb_lab_normalized(im):
    # Convert to numpy array
    rgb_array = np.array(im)

    # Normalize RGB values from 0 to 1
    rgb_array_normalized = rgb_array / 255.0

    # Convert RGB to LAB colorspace
    lab_array_normalized = color.rgb2lab(rgb_array_normalized)

    # Scale LAB values to range [0, 1]
    lab_array_normalized[..., 0] = (lab_array_normalized[..., 0]) / 100.0
    lab_array_normalized[..., 1] = (lab_array_normalized[..., 1] + 128) / 255.0
    lab_array_normalized[..., 2] = (lab_array_normalized[..., 2] + 128) / 255.0

    # Convert LAB array back to image
    lab_image_normalized = Image.fromarray((lab_array_normalized * 255).astype(np.uint8), mode='LAB')
    return lab_image_normalized



data = []

input = Image.open(file_path + "Training/TRAIN_INPUT_[04] Coming into Bloom.png").convert('RGB')
input = np.array(crop(rgb_lab_normalized(input)))
print("Done reading the input of size = ", input.shape)

output = Image.open(file_path + "Training/TRAIN_OUTPUT_[04] Coming into Bloom.png").convert('RGB')
output = np.array(crop(rgb_lab_normalized(output)))
print("Done reading the input of size = ", output.shape)


train_input = []
test_input = []
for i in range(0,len(input)):
    if i % 4 == 0:
        test_input.append(input[i])
    else:
        train_input.append(input[i])

train_input = np.array(train_input)
test_input = np.array(test_input)

print("Done reading the train input of size = ", train_input.shape)
print("Done reading the test input of size = ", test_input.shape)
input = []

train_output = []
test_output = []
for i in range(0,len(output)):
    if i % 4 == 0:
        test_output.append(output[i])
    else:
        train_output.append(output[i])

train_output = np.array(train_output)
test_output = np.array(test_output)

print("Done reading the train output of size = ", train_input.shape)
print("Done reading the test output of size = ", test_input.shape)

output = []
# Out:
# Done reading the input of size =  (1800, 128, 128, 3)
# Done reading the input of size =  (1800, 128, 128, 3)
# Done reading the train input of size =  (1350, 128, 128, 3)
# Done reading the test input of size =  (450, 128, 128, 3)
# Done reading the train output of size =  (1350, 128, 128, 3)
# Done reading the test output of size =  (450, 128, 128, 3)

# %%
N = 100
n = 10
plt.figure(figsize=(10, 4))
for i in range(0,10):

    ax = plt.subplot(2, n, i + 1)


    plt.title("input")
    plt.imshow((train_input[i+N]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    bx = plt.subplot(2, n, i + n + 1)
    plt.title("output")
    plt.imshow((train_output[i+N]))
    plt.gray()
    bx.get_xaxis().set_visible(False)
    bx.get_yaxis().set_visible(False)
plt.show()

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization
from tensorflow.keras import layers, losses
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate

from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate

def unet_model(input_shape=(size, size, 3)):
    inputs = Input(input_shape)

    # Contracting Path
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(inputs)
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(conv1)

    conv2 = Conv2D(128, 3, activation='relu', padding='same', strides = 2)(conv1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same')(conv2)

    conv3 = Conv2D(256, 3, activation='relu', padding='same', strides = 2)(conv2)
    conv3 = Conv2D(256, 3, activation='relu', padding='same')(conv3)

    conv4 = Conv2D(512, 3, activation='relu', padding='same', strides = 2)(conv3)
    conv4 = Conv2D(512, 3, activation='relu', padding='same')(conv4)

    conv5 = concatenate([Conv2DTranspose(256, kernel_size=3, strides=2, activation='relu', padding='same')(conv4), conv3], axis = -1)
    conv5 = Conv2D(128, 3, activation='relu', padding='same')(conv5)

    conv6 = concatenate([Conv2DTranspose(128, kernel_size=3, strides=2, activation='relu', padding='same')(conv5), conv2], axis = -1)
    conv6 = Conv2D(128, 3, activation='relu', padding='same')(conv6)

    conv7 = concatenate([Conv2DTranspose(64, kernel_size=3, strides=2, activation='relu', padding='same')(conv6), conv1], axis = -1)
    conv7 = Conv2D(64, 3, activation='relu', padding='same')(conv7)

    # Output Layer
    output = Conv2D(3, kernel_size=(3, 3), activation='sigmoid', padding='same')(conv7)

    model = Model(inputs=inputs, outputs=output)
    return model

# Usage example:
unet = unet_model()
unet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 128, 128, 64)         1792      ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 64)         36928     ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 128)          73856     ['conv2d_1[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 128)          147584    ['conv2d_2[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 256)          295168    ['conv2d_3[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 256)          590080    ['conv2d_4[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 512)          1180160   ['conv2d_5[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 512)          2359808   ['conv2d_6[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 256)          1179904   ['conv2d_7[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 32, 32, 512)          0         ['conv2d_transpose[0][0]',
#                                                                      'conv2d_5[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 128)          589952    ['concatenate[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 64, 128)          147584    ['conv2d_8[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 64, 64, 256)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'conv2d_3[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 64, 64, 128)          295040    ['concatenate_1[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 128, 64)         73792     ['conv2d_9[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 128, 128, 128)        0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 128, 128, 64)         73792     ['concatenate_2[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 128, 128, 3)          1731      ['conv2d_10[0][0]']
#
# ==================================================================================================
# Total params: 7047171 (26.88 MB)
# Trainable params: 7047171 (26.88 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from keras.optimizers import Adam
opt = Adam(learning_rate=0.0001)
unet.compile(optimizer=opt, loss=losses.MeanSquaredError())
start = time.time()
model = unet.fit(train_input, train_output,
                epochs=epoch,
                shuffle=True,
                validation_data=(test_input, test_output),batch_size=16)

# record end time
end = time.time()

print("The time of execution of above program is :",
      (end-start), "seconds")

unet.save(file_path + 'Model/unet_' + str(model_number))

loss = model.history['loss']
loss = pd.DataFrame(loss)
loss.to_csv(file_path + 'Model/loss_'+ str(model_number) + '.csv')
val_loss = model.history['val_loss']
val_loss = pd.DataFrame(val_loss)
val_loss.to_csv(file_path  +'Model/val_loss_'+ str(model_number)+ '.csv')
# Out:
# Epoch 1/100
# 85/85 [==============================] - 43s 282ms/step - loss: 0.0061 - val_loss: 0.0016
# Epoch 2/100
# 85/85 [==============================] - 15s 175ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 3/100
# 85/85 [==============================] - 15s 178ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 4/100
# 85/85 [==============================] - 15s 177ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 5/100
# 85/85 [==============================] - 15s 176ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 6/100
# 85/85 [==============================] - 16s 188ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 7/100
# 85/85 [==============================] - 15s 175ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 8/100
# 85/85 [==============================] - 15s 176ms/step - loss: 0.0010 - val_loss: 9.7499e-04
# Epoch 9/100
# 85/85 [==============================] - 15s 176ms/step - loss: 9.7606e-04 - val_loss: 9.6465e-04
# Epoch 10/100
# 85/85 [==============================] - 16s 190ms/step - loss: 9.6433e-04 - val_loss: 9.2178e-04
# Epoch 11/100
# 85/85 [==============================] - 16s 183ms/step - loss: 9.1133e-04 - val_loss: 0.0012
# Epoch 12/100
# 85/85 [==============================] - 16s 190ms/step - loss: 8.7807e-04 - val_loss: 8.5188e-04
# Epoch 13/100
# 85/85 [==============================] - 15s 179ms/step - loss: 8.7919e-04 - val_loss: 9.0250e-04
# Epoch 14/100
# 85/85 [==============================] - 16s 183ms/step - loss: 8.9202e-04 - val_loss: 8.3580e-04
# Epoch 15/100
# 85/85 [==============================] - 15s 181ms/step - loss: 8.5511e-04 - val_loss: 8.2503e-04
# Epoch 16/100
# 85/85 [==============================] - 15s 180ms/step - loss: 8.1822e-04 - val_loss: 8.2156e-04
# Epoch 17/100
# 85/85 [==============================] - 16s 193ms/step - loss: 7.9052e-04 - val_loss: 7.8600e-04
# Epoch 18/100
# 85/85 [==============================] - 15s 176ms/step - loss: 7.8955e-04 - val_loss: 7.8843e-04
# Epoch 19/100
# 85/85 [==============================] - 15s 176ms/step - loss: 7.7913e-04 - val_loss: 7.9128e-04
# Epoch 20/100
# 85/85 [==============================] - 15s 178ms/step - loss: 7.6295e-04 - val_loss: 8.3667e-04
# Epoch 21/100
# 85/85 [==============================] - 16s 189ms/step - loss: 7.8450e-04 - val_loss: 7.3701e-04
# Epoch 22/100
# 85/85 [==============================] - 15s 178ms/step - loss: 7.5296e-04 - val_loss: 7.5949e-04
# Epoch 23/100
# 85/85 [==============================] - 15s 178ms/step - loss: 7.3533e-04 - val_loss: 7.1148e-04
# Epoch 24/100
# 85/85 [==============================] - 15s 182ms/step - loss: 7.2261e-04 - val_loss: 7.2877e-04
# Epoch 25/100
# 85/85 [==============================] - 17s 197ms/step - loss: 7.0785e-04 - val_loss: 7.2264e-04
# Epoch 26/100
# 85/85 [==============================] - 15s 180ms/step - loss: 7.2824e-04 - val_loss: 6.8420e-04
# Epoch 27/100
# 85/85 [==============================] - 15s 181ms/step - loss: 7.2391e-04 - val_loss: 6.7651e-04
# Epoch 28/100
# 85/85 [==============================] - 15s 180ms/step - loss: 6.6227e-04 - val_loss: 7.4285e-04
# Epoch 29/100
# 85/85 [==============================] - 15s 181ms/step - loss: 6.6348e-04 - val_loss: 6.5235e-04
# Epoch 30/100
# 85/85 [==============================] - 15s 179ms/step - loss: 6.4684e-04 - val_loss: 6.6274e-04
# Epoch 31/100
# 85/85 [==============================] - 15s 181ms/step - loss: 6.3169e-04 - val_loss: 6.5739e-04
# Epoch 32/100
# 85/85 [==============================] - 15s 180ms/step - loss: 6.4492e-04 - val_loss: 6.3549e-04
# Epoch 33/100
# 85/85 [==============================] - 16s 189ms/step - loss: 6.3481e-04 - val_loss: 6.4536e-04
# Epoch 34/100
# 85/85 [==============================] - 15s 176ms/step - loss: 6.1267e-04 - val_loss: 6.4146e-04
# Epoch 35/100
# 85/85 [==============================] - 15s 176ms/step - loss: 5.9210e-04 - val_loss: 6.1553e-04
# Epoch 36/100
# 85/85 [==============================] - 15s 176ms/step - loss: 5.7737e-04 - val_loss: 6.2068e-04
# Epoch 37/100
# 85/85 [==============================] - 15s 177ms/step - loss: 5.6843e-04 - val_loss: 5.7876e-04
# Epoch 38/100
# 85/85 [==============================] - 15s 181ms/step - loss: 5.5693e-04 - val_loss: 5.4385e-04
# Epoch 39/100
# 85/85 [==============================] - 15s 181ms/step - loss: 5.7026e-04 - val_loss: 6.6990e-04
# Epoch 40/100
# 85/85 [==============================] - 17s 195ms/step - loss: 5.5212e-04 - val_loss: 6.1324e-04
# Epoch 41/100
# 85/85 [==============================] - 16s 195ms/step - loss: 5.4317e-04 - val_loss: 5.2523e-04
# Epoch 42/100
# 85/85 [==============================] - 16s 191ms/step - loss: 5.1390e-04 - val_loss: 5.7581e-04
# Epoch 43/100
# 85/85 [==============================] - 16s 190ms/step - loss: 4.9304e-04 - val_loss: 5.0637e-04
# Epoch 44/100
# 85/85 [==============================] - 16s 189ms/step - loss: 4.9805e-04 - val_loss: 4.7785e-04
# Epoch 45/100
# 85/85 [==============================] - 15s 176ms/step - loss: 4.8925e-04 - val_loss: 5.2712e-04
# Epoch 46/100
# 85/85 [==============================] - 16s 189ms/step - loss: 4.9452e-04 - val_loss: 4.4928e-04
# Epoch 47/100
# 85/85 [==============================] - 15s 178ms/step - loss: 4.9236e-04 - val_loss: 6.0817e-04
# Epoch 48/100
# 85/85 [==============================] - 16s 194ms/step - loss: 4.4399e-04 - val_loss: 5.6094e-04
# Epoch 49/100
# 85/85 [==============================] - 15s 181ms/step - loss: 4.4922e-04 - val_loss: 4.4006e-04
# Epoch 50/100
# 85/85 [==============================] - 16s 194ms/step - loss: 4.4069e-04 - val_loss: 4.7962e-04
# Epoch 51/100
# 85/85 [==============================] - 16s 191ms/step - loss: 4.1314e-04 - val_loss: 4.3486e-04
# Epoch 52/100
# 85/85 [==============================] - 16s 189ms/step - loss: 4.1208e-04 - val_loss: 4.5712e-04
# Epoch 53/100
# 85/85 [==============================] - 16s 189ms/step - loss: 4.3079e-04 - val_loss: 4.0107e-04
# Epoch 54/100
# 85/85 [==============================] - 15s 176ms/step - loss: 3.9064e-04 - val_loss: 4.7490e-04
# Epoch 55/100
# 85/85 [==============================] - 16s 190ms/step - loss: 3.8982e-04 - val_loss: 4.0040e-04
# Epoch 56/100
# 85/85 [==============================] - 15s 176ms/step - loss: 3.7266e-04 - val_loss: 4.0230e-04
# Epoch 57/100
# 85/85 [==============================] - 16s 189ms/step - loss: 3.5862e-04 - val_loss: 3.7693e-04
# Epoch 58/100
# 85/85 [==============================] - 15s 176ms/step - loss: 3.5885e-04 - val_loss: 4.3708e-04
# Epoch 59/100
# 85/85 [==============================] - 15s 176ms/step - loss: 3.4940e-04 - val_loss: 3.8472e-04
# Epoch 60/100
# 85/85 [==============================] - 16s 189ms/step - loss: 3.3184e-04 - val_loss: 3.4619e-04
# Epoch 61/100
# 85/85 [==============================] - 15s 176ms/step - loss: 3.4984e-04 - val_loss: 3.5064e-04
# Epoch 62/100
# 85/85 [==============================] - 16s 189ms/step - loss: 3.3183e-04 - val_loss: 3.5575e-04
# Epoch 63/100
# 85/85 [==============================] - 16s 189ms/step - loss: 3.4137e-04 - val_loss: 3.6597e-04
# Epoch 64/100
# 85/85 [==============================] - 15s 176ms/step - loss: 3.0807e-04 - val_loss: 3.1712e-04
# Epoch 65/100
# 85/85 [==============================] - 16s 190ms/step - loss: 2.9719e-04 - val_loss: 3.0799e-04
# Epoch 66/100
# 85/85 [==============================] - 15s 176ms/step - loss: 2.9410e-04 - val_loss: 3.0136e-04
# Epoch 67/100
# 85/85 [==============================] - 15s 176ms/step - loss: 2.8858e-04 - val_loss: 3.4105e-04
# Epoch 68/100
# 85/85 [==============================] - 16s 190ms/step - loss: 3.2815e-04 - val_loss: 3.4074e-04
# Epoch 69/100
# 85/85 [==============================] - 16s 190ms/step - loss: 3.1387e-04 - val_loss: 2.8543e-04
# Epoch 70/100
# 85/85 [==============================] - 16s 189ms/step - loss: 2.7637e-04 - val_loss: 2.8181e-04
# Epoch 71/100
# 85/85 [==============================] - 15s 176ms/step - loss: 2.6102e-04 - val_loss: 2.9264e-04
# Epoch 72/100
# 85/85 [==============================] - 15s 176ms/step - loss: 2.7330e-04 - val_loss: 3.0975e-04
# Epoch 73/100
# 85/85 [==============================] - 15s 176ms/step - loss: 2.5905e-04 - val_loss: 2.9650e-04
# Epoch 74/100
# 85/85 [==============================] - 15s 176ms/step - loss: 2.5330e-04 - val_loss: 2.6829e-04
# Epoch 75/100
# 85/85 [==============================] - 15s 176ms/step - loss: 2.5976e-04 - val_loss: 2.9577e-04
# Epoch 76/100
# 85/85 [==============================] - 15s 177ms/step - loss: 2.5787e-04 - val_loss: 2.7320e-04
# Epoch 77/100
# 85/85 [==============================] - 15s 177ms/step - loss: 2.5963e-04 - val_loss: 2.6429e-04
# Epoch 78/100
# 85/85 [==============================] - 16s 189ms/step - loss: 2.4508e-04 - val_loss: 2.5267e-04
# Epoch 79/100
# 85/85 [==============================] - 16s 189ms/step - loss: 2.5289e-04 - val_loss: 2.7469e-04
# Epoch 80/100
# 85/85 [==============================] - 16s 190ms/step - loss: 2.3797e-04 - val_loss: 2.4276e-04
# Epoch 81/100
# 85/85 [==============================] - 15s 177ms/step - loss: 2.4048e-04 - val_loss: 2.6878e-04
# Epoch 82/100
# 85/85 [==============================] - 16s 190ms/step - loss: 2.4214e-04 - val_loss: 2.5112e-04
# Epoch 83/100
# 85/85 [==============================] - 15s 176ms/step - loss: 2.4640e-04 - val_loss: 2.7722e-04
# Epoch 84/100
# 85/85 [==============================] - 16s 189ms/step - loss: 2.2438e-04 - val_loss: 2.4716e-04
# Epoch 85/100
# 85/85 [==============================] - 15s 176ms/step - loss: 2.4498e-04 - val_loss: 2.4484e-04
# Epoch 86/100
# 85/85 [==============================] - 16s 190ms/step - loss: 2.3959e-04 - val_loss: 2.3815e-04
# Epoch 87/100
# 85/85 [==============================] - 16s 190ms/step - loss: 2.1242e-04 - val_loss: 2.2297e-04
# Epoch 88/100
# 85/85 [==============================] - 16s 189ms/step - loss: 2.3081e-04 - val_loss: 3.2559e-04
# Epoch 89/100
# 85/85 [==============================] - 15s 176ms/step - loss: 3.3817e-04 - val_loss: 2.5081e-04
# Epoch 90/100
# 85/85 [==============================] - 15s 176ms/step - loss: 2.1964e-04 - val_loss: 2.4560e-04
# Epoch 91/100
# 85/85 [==============================] - 15s 177ms/step - loss: 2.1312e-04 - val_loss: 2.4544e-04
# Epoch 92/100
# 85/85 [==============================] - 15s 176ms/step - loss: 2.1162e-04 - val_loss: 2.3586e-04
# Epoch 93/100
# 85/85 [==============================] - 16s 189ms/step - loss: 1.9674e-04 - val_loss: 2.3432e-04
# Epoch 94/100
# 85/85 [==============================] - 16s 189ms/step - loss: 1.9364e-04 - val_loss: 2.2774e-04
# Epoch 95/100
# 85/85 [==============================] - 15s 176ms/step - loss: 1.9155e-04 - val_loss: 2.0928e-04
# Epoch 96/100
# 85/85 [==============================] - 16s 190ms/step - loss: 1.9136e-04 - val_loss: 2.0609e-04
# Epoch 97/100
# 85/85 [==============================] - 15s 176ms/step - loss: 1.8091e-04 - val_loss: 2.0945e-04
# Epoch 98/100
# 85/85 [==============================] - 15s 177ms/step - loss: 2.0658e-04 - val_loss: 2.5235e-04
# Epoch 99/100
# 85/85 [==============================] - 16s 190ms/step - loss: 2.0102e-04 - val_loss: 2.4170e-04
# Epoch 100/100
# 85/85 [==============================] - 16s 190ms/step - loss: 1.9898e-04 - val_loss: 2.1457e-04
# The time of execution of above program is : 1585.3604061603546 seconds

# %%
from tensorflow import keras
from PIL import Image, ImageOps
import numpy as np
import PIL
PIL.Image.MAX_IMAGE_PIXELS = 236958876

n_size = size

def lab_rgb_unnormalized(lab_image):
    # Convert LAB image to numpy array
    lab_array = np.array(lab_image/255)

    # Scale LAB values back to their original ranges
    lab_array[..., 0] = lab_array[..., 0] * 100.0
    lab_array[..., 1] = (lab_array[..., 1] * 255.0) - 128
    lab_array[..., 2] = (lab_array[..., 2] * 255.0) - 128

    # Convert LAB to RGB colorspace
    rgb_array_unnormalized = color.lab2rgb(lab_array)

    # Scale RGB values back to the range [0, 255]
    rgb_array_unnormalized = (rgb_array_unnormalized * 255).astype(np.uint8)

    # Convert RGB array back to image
    rgb_image_unnormalized = Image.fromarray(rgb_array_unnormalized, mode='RGB')
    return rgb_image_unnormalized

def crop_(im):
    width, height = im.size
    data = []
    for j in range(0,int(height/n_size)):
        for i in range(0,int(width/n_size)):
            im1 = im.crop((0 + (n_size*i), 0 + (n_size*j), n_size + (n_size*i), n_size + (n_size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            data.append(im1)
    return data


#filename = str('[WB] 1885_Mactan_NAP_FelixPelayo.png')
#filename = str("1885_Mactan_NAP_FelixPelayo.tiff")
#filename = str("[WB] 1872_Mindanao_NAP_D.FedericoCaballero.tif")
#filename = str("[WB] XXXX_Cagayan y Ilocos_online.png")
filename = str("TEST_INPUT_[04] Coming into Bloom.png")
test = Image.open(file_path+ "Testing/" + filename).convert('RGB')
test = rgb_lab_normalized(test)
w_dirty, h_dirty = test.size


autoencoder = keras.models.load_model(file_path + 'Model/unet_128')


xx = int(w_dirty/n_size)
final=[]

for portion in range(0,xx):
    im1 = test.crop((n_size*portion, 0, (n_size*portion) + n_size, h_dirty))
    w1, h1 = im1.size
    w = int(w1/n_size)
    h = int(h1/n_size)

    neverbeforeseen = np.array(crop_(im1))
    #encoded_imgs = autoencoder.encoder(neverbeforeseen).numpy()
    decoded_imgs = autoencoder.predict(neverbeforeseen)

    col = np.vstack((decoded_imgs[0],decoded_imgs[1]))
    for i in range(2,h):
        col = np.vstack((col,decoded_imgs[i]))

    #y = np.where(col > 0.5,1,0) #round the values
    y = col
    y = (y * 255).astype('uint8')
    if portion == 0:
        final = y
    if portion > 0:
        final = np.hstack((final,y))


final = lab_rgb_unnormalized(final)
final = np.squeeze(final)
reconstructed = Image.fromarray(final)
reconstructed.save(file_path + "Testing/"+"CLEAN_"+filename)
# Out:
# 1/1 [==============================] - 0s 276ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
