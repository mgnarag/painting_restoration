# %% [markdown]
# <a href="https://colab.research.google.com/github/mgnarag/painting_restoration/blob/main/unet_L.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !ls drive/My\ Drive
file_path = "/content/drive/MyDrive/Baumgartner screenshots/"
# Out:
# '107.1 syllabus 1SAY1920 FINAL.gdoc'
# '1C-01 Narag et al (1).pdf'
# '1C-01 Narag et al.pdf'
# '1FA971504AC646559D05A8ED6341AFB3[1025340].png'
# '1H-04 Narag et al.pdf'
#  20220802_182749.heic
#  20220802_182831.heic
#  20220802_183259.heic
#  20220803_125819.heic
#  20220803_125842.heic
#  20220803_144229.heic
#  20220803_144422.heic
#  20220803_160724.heic
#  20220803_160751.heic
#  20220803_165240.heic
#  20220803_165318.heic
#  20220803_174701.heic
#  20220803_174706.heic
#  20220804_175217.heic
#  20220804_175443.heic
#  20220804_175616.heic
#  20220804_181917.heic
#  20220804_182007.heic
#  20220804_182117.heic
#  2S22-23_LE3-Regular-Set-A-FINAL-KEY.pdf
# '3 classes (polarized)CM_alexnet.png'
# '3 classes (polarized)CM_vgg.png'
# 'A4_Physics 71 TWHFU-3_gradesheet (1).pdf'
# 'A4_Physics 71 TWHFU-3_officialgrades (1).pdf'
# 'A4_Physics 71 TWHFU-3_officialgrades.gdoc'
# 'Abstract - NARAG, Mark Jeremy.pdf'
# 'Annex 1 (copy of Journal).pdf'
# 'Annex 2 (Proof of employments).pdf'
# 'App Physics 181 THY-FX-2_studentcontactlist.xlsx'
#  Architectural_designs
# 'Arki abstract.pdf'
# 'Arki full paper.pdf'
# '[ART] Example of Objectives - Activities - Exp Output OPTIKAL WBS version 2.gsheet'
#  autoencoder_fine_tuned_6
# 'autoencoder_fine_tuned_6 (1)'
#  autoencoder_fine_tuned_6_b
# 'Baumgartner screenshots'
# 'Binarizing architectural drawings'
#  classification_report_nonTL.xlsx
#  classification_report.xlsx
#  Classroom
# 'CLEAN_TEST_INPUT_[04] Coming into Bloom.png'
# 'Colab Notebooks'
# 'Color Difference Specification 2016.pptx'
#  confusion_matrix_nonTL.png
#  confusion_matrix_nonTL.xlsx
#  CS284
#  CS_NIP_201819_S2_BS_AppliedPhysics_Narag_Mark_Jeremy.pdf
#  D54dUVpU8AIZzoD.jpeg
#  Data.tex
# 'Dormitory Stay Request MNarag.docx.pdf'
# '[DRAFT-ART] UP Intelligent Systems Center Research Grant Application - Preview.docx'
#  DrzPc0sUwAAyQHi.jpeg
#  DvO96koV4AAD6PP.jpeg
# 'DvO976tVAAEQ9ym (1).jpeg'
#  DvO976tVAAEQ9ym.jpeg
# 'Employment Survey.gdoc'
#  Fast-Dreambooth
# 'FBC-2_Banez (1).pdf'
#  FBC-2_Banez.pdf
#  FdUaD2nUcAAki1b.jpeg
# 'Figure 1.png'
# 'Figure 2.png'
# 'fingerprint (1).pb'
# 'fingerprint (2).pb'
# 'fingerprint (3).pb'
# 'fingerprint (4).pb'
# 'fingerprint (5).pb'
#  fingerprint.pb
# 'Form5a and Grades.zip'
#  Fringes.zip
#  FSR_120201_NARAG_MARK_JEREMY_GACIAS_NIP.pdf
#  FSR_120202_NARAG_MARK_JEREMY_GACIAS_NIP.pdf
#  FSR_120212_NARAG_MARK_JEREMY_GACIAS_NIP.pdf
#  FSR_120221_NARAG_MARK_JEREMY_GACIAS_NIP.pdf
# 'Geology (Ate Grass)'
# 'Geology (Ate Grass) (1)'
# 'Getting started.pdf'
#  IMG_4258.HEIC
#  IMG_4259.HEIC
#  IMG_4260.HEIC
#  IMG_4261.HEIC
#  IMG_4262.HEIC
#  IMG_4263.HEIC
#  IMG_4288.HEIC
#  IMG_5634.JPG
#  IMG_6572.jpeg
#  IMG_6578.jpeg
# 'IMG_6587 (1).jpeg'
#  IMG_6587.jpeg
#  IPA-Form4.1-2021Rev072021-1.pdf
#  IPA-Form4.2-2021Rev072021.docx
#  IPA-Form4.3-2021Rev072021.pdf
# 'item sample.tex'
# 'item template.tex'
# 'Jas Jem utang.gsheet'
#  Jem_face
# 'JFR Reduced Fees for 1st Sem AY 20-21.zip'
# 'Lecture 22 - Torque.pptx'
# 'Lecture 23 - Dynamics of Rotation.pptx'
# 'Lecture 24 - Angular Momentum.pptx'
# 'Lecture 25 - Equilibrium and Center of Gravity.pptx'
# 'Lecture 26 - Density and Pressure in a Fluid.pptx'
# 'Lecture 27 - Buoyancy.pptx'
# 'LRM_20220804_195432 (1).dng'
#  LRM_20220804_195432.dng
#  LRM_20220804_195500.dng
#  LRM_20220804_195546.dng
#  LRM_20220805_113837.dng
#  LRM_20220805_142837.dng
#  LRM_20220805_143054.dng
#  LRM_20220805_143817.dng
# 'MALIPOL_CHAE ANN.pdf'
#  Metric_100dpi.csv
#  Metric_500.csv
# 'NARAG_MARKJEREMY (1).BC.pdf'
#  NARAG_MARKJEREMY.BC.pdf
#  NARAG_MARKJEREMY.CC.png
#  NARAG_MARKJEREMY.dcog.pdf
#  NARAG_MARKJEREMY.DC.pdf
#  NARAG_MARKJEREMY.FL.pdf
#  NARAG_MARKJEREMY.Form1.1.pdf
#  NARAG_MARKJEREMY.POS.pdf
#  NARAG_MARKJEREMY.SD.pdf
#  NARAG_MARKJEREMY.TCGTOR.pdf
# '[NARAG] Physics 242 Final Report.pdf'
# '[NARAG] Physics 242 PS 1.pdf'
# '[NARAG] Physics 242 PS 2.pdf'
# 'Narag SPP Cert.pdf'
#  NARAG_Travel-Report-Form-2019.pdf
# 'NIP COVID-19 Case Report Form.gform'
# 'NIP COVID-19 Case Report Form (Responses).gsheet'
# 'NIP COVID19 Report.gsheet'
# 'NIP Year End Party 2022'
#  NRAG_MARKJEREMY.OTRTCG.pdf
# 'Optics in Art and Art Analysis (1).pptx'
# 'Optics in Art and Art Analysis.pptx'
# 'OUR CErtificate.gdoc'
# 'OUR CErtificate.pdf'
# 'output v1_100dpi.png'
# 'output v2_100dpi.png'
# 'output v3_100dpi.png'
# 'output v3_500.png'
# 'output v4_100dpi.png'
# 'output v5_100dpi.png'
# 'output v6_100dpi.png'
# 'OVCRD IPA Reference Slip (2021-0929-1691-5873).pdf'
# 'PA-08 Narag et al.pdf'
#  PA-08.pdf
# 'Parallel Presentation.gslides'
# 'PEER EVALUTION - Physics 72.1 HBC-1 .gform'
# 'PEER EVALUTION - Physics 72.1 TDE-1 .gform'
# 'PEER EVALUTION - Physics 72.1 WDE-1 .gform'
# 'PhD Candidacy Slides.pdf'
# 'PhD Candidacy Slides.pptx'
# 'Physics 107.1 Drive'
# 'Physics 107.1 MBCD-2_studentcontactlist.xlsx'
#  Physics305_plasma
# 'Physics 71.1 WIJ FIJ and 72.1 TBC.gsheet'
#  Physics_71_Syllabus.zip
# 'Physics_71_Syllabus.zip (Unzipped Files)'
# '[Physics 71 V-2] Attendance.gsheet'
# 'Physics 72.1 2nd Sem AY 2019-2020.gsheet'
# 'Rene Jem utang.gsheet'
# 'Research files'
# 'Sablay picture.jpeg'
# 'saved_model (1).pb'
# 'saved_model (2).pb'
# 'saved_model (3).pb'
# 'saved_model (4).pb'
# 'saved_model (5).pb'
#  saved_model.pb
# 'Screenshot 2023-02-12 at 12.13.51 (1).png'
# 'Screenshot 2023-02-12 at 12.13.51.png'
# 'Screenshot 2023-06-29 at 19.20.04.png'
# 'Screenshot 2023-06-29 at 19.26.09.png'
#  sd
#  Smokers.mp4
# 'SORRY SIR HUHU.gdoc'
# 'SORRY SIR HUHU.pdf'
# 'SPP-2023-1H-04 (1).pptx'
#  SPP-2023-1H-04.pptx
#  SPP_2023-Contributed-26.pdf
# 'SPP-2023-PB-05  .pdf'
#  SPP_Appearance-45.pdf
# 'SPP Cert of Appearance NARAG (1).pdf'
# 'SPP Cert of Appearance NARAG (2).pdf'
# 'SPP Cert of Appearance NARAG.pdf'
# 'Testing on DIV2K dataset.pdf'
# '[THY-FX] Physics 181 LE1 Submissions 2nd Sem AY 2020-21'
#  Travel-Report-Form-2019.pdf
# 'Undergraduate Research'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet.gsheet'
# '[Updated] Physics 71 THQ-FQ-1_studentcontactlist (1).xlsx'
# '[Updated] Physics 71 THQ-FQ-1_studentcontactlist.xlsx'
# 'variables (1).data-00000-of-00001'
# 'variables (2).data-00000-of-00001'
# 'variables (3).data-00000-of-00001'
# 'variables (4).data-00000-of-00001'
# 'variables (5).data-00000-of-00001'
#  variables.data-00000-of-00001
# 'Waiver for more than 18 units [2nd sem AY 20-21].gdoc'

# %% [markdown]
# ## Installing packages

# %%
import time
import pandas as pd

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

from PIL import Image, ImageOps
import os
import numpy as np

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from scipy.ndimage import zoom

import cv2
from skimage import color

from tensorflow import keras
from PIL import Image, ImageOps
import numpy as np
import PIL
PIL.Image.MAX_IMAGE_PIXELS = 236958876
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Defining functions

# %%
def zoom_and_resize(img, zoom_factor):
    height, width = img.shape[:2]
    crop_top = int((height - height / zoom_factor) / 2)# Calculate the region to crop around the center
    crop_bottom = int(height - crop_top)
    crop_left = int((width - width / zoom_factor) / 2)
    crop_right = int(width - crop_left)
    cropped_image = img[crop_top:crop_bottom, crop_left:crop_right]    # Crop the image
    resized_image = cv2.resize(cropped_image, (width, height))# Resize the zoomed image back to the original dimensions
    return resized_image

def crop(im):
    width, height = im.size
    data = []
    step = int(size * 0.80)  # Adjust the step size for cropping
    for j in range(0, height, step):
        for i in range(0, width, step):
            if i + size <= width and j + size <= height:
                im1 = im.crop((i, j, i + size, j + size))
                im1 = np.array(im1).astype(np.float32)
                data.append(im1/255)
                im1 = np.rot90(im1)
                data.append(im1/255)
                #im1 = np.rot90(im1)
                #data.append(im1/255)
                #im1 = np.rot90(im1)
                #data.append(im1/255)
                #for z in zoom_factor:
                #    zoomed_img = zoom_and_resize(im1, z)
                #    data.append(zoomed_img/255)
    return data

def rgb_lab_normalized(im):
    rgb_array = np.array(im) # Convert to numpy array
    rgb_array_normalized = rgb_array / 255.0 # Normalize RGB values from 0 to 1
    lab_array_normalized = color.rgb2lab(rgb_array_normalized) # Convert RGB to LAB colorspace
    lab_array_normalized[..., 0] = (lab_array_normalized[..., 0]) / 100.0 # Scale LAB values to range [0, 1]
    lab_array_normalized[..., 1] = (lab_array_normalized[..., 1] + 128) / 255.0
    lab_array_normalized[..., 2] = (lab_array_normalized[..., 2] + 128) / 255.0
    lab_image_normalized = Image.fromarray((lab_array_normalized * 255).astype(np.uint8), mode='LAB')# Convert LAB array back to image
    return lab_image_normalized

# %% [markdown]
# ## Preparing the training dataset

# %%
size = 32
model_number = size

#zoom_factor = [1.50, 2.0, 2.50, 3.0]
input = []
output = []

input_folder_path = file_path + 'Training/input/'
output_folder_path = file_path + 'Training/output/'
# List all files in the directory
input_files = os.listdir(input_folder_path)
output_files = os.listdir(output_folder_path)

for image_file in input_files:
    image_path = os.path.join(input_folder_path, image_file)
    image = Image.open(image_path).convert('RGB')
    image = rgb_lab_normalized(image)
    image = crop(image)
    input.extend(image)

for image_file in output_files:
    image_path = os.path.join(output_folder_path, image_file)
    image = Image.open(image_path).convert('RGB')
    image = rgb_lab_normalized(image)
    image = crop(image)
    output.extend(image)
input = np.array(input)
output = np.array(output)

print("Done reading the input of size = ", input.shape)
print("Done reading the output of size = ", output.shape)

# Split the data into training and testing sets
train_input, test_input, train_output, test_output = train_test_split(
    input, output, test_size=0.2, random_state=42)


input = []
output = []

train_output = train_output[:,:,:,0:1]
train_input = train_input[:,:,:,0:1]
test_output = test_output[:,:,:,0:1]
test_input = test_input[:,:,:,0:1]

print("Done reading the train input of size = ", train_input.shape)
print("Done reading the test input of size = ", test_input.shape)
print("Done reading the train output of size = ", train_input.shape)
print("Done reading the test output of size = ", test_input.shape)
# Out:
# Done reading the input of size =  (35136, 32, 32, 3)
# Done reading the output of size =  (35136, 32, 32, 3)
# Done reading the train input of size =  (28108, 32, 32, 1)
# Done reading the test input of size =  (7028, 32, 32, 1)
# Done reading the train output of size =  (28108, 32, 32, 1)
# Done reading the test output of size =  (7028, 32, 32, 1)

# %%
import matplotlib.pyplot as plt

N = 2000
n = 10
plt.figure(figsize=(10, 4))

for i in range(n):
    ax = plt.subplot(4, n, i + 1)
    plt.title("in ch1")
    plt.imshow(train_input[i + N][:,:,0], cmap='gray')
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    bx = plt.subplot(4, n, i + n + 1)
    plt.title("out ch1")
    plt.imshow(train_output[i + N][:,:,0], cmap='gray')
    plt.gray()
    bx.get_xaxis().set_visible(False)
    bx.get_yaxis().set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Creating the Unet model

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization
from tensorflow.keras import layers, losses
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate

from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate

def unet_model(input_shape=(size, size, 1)):
    inputs = Input(input_shape)

    # Contracting Path
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(inputs)
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(conv1)

    conv2 = Conv2D(128, 3, activation='relu', padding='same', strides = 2)(conv1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same')(conv2)

    conv3 = Conv2D(256, 3, activation='relu', padding='same', strides = 2)(conv2)
    conv3 = Conv2D(256, 3, activation='relu', padding='same')(conv3)

    #conv4 = Conv2D(512, 3, activation='relu', padding='same', strides = 2)(conv3)
    #conv4 = Conv2D(512, 3, activation='relu', padding='same')(conv4)

    #conv5 = concatenate([Conv2DTranspose(256, kernel_size=3, strides=2, activation='relu', padding='same')(conv4), conv3], axis = -1)
    #conv5 = Conv2D(128, 3, activation='relu', padding='same')(conv5)

    conv6 = concatenate([Conv2DTranspose(128, kernel_size=3, strides=2, activation='relu', padding='same')(conv3), conv2], axis = -1)
    conv6 = Conv2D(128, 3, activation='relu', padding='same')(conv6)

    conv7 = concatenate([Conv2DTranspose(64, kernel_size=3, strides=2, activation='relu', padding='same')(conv6), conv1], axis = -1)
    conv7 = Conv2D(64, 3, activation='relu', padding='same')(conv7)

    # Output Layer
    output = Conv2D(1, kernel_size=(3, 3), activation='sigmoid', padding='same')(conv7)

    model = Model(inputs=inputs, outputs=output)
    return model

# Usage example:
unet = unet_model()
unet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 1)]          0         []
#
#  conv2d (Conv2D)             (None, 32, 32, 64)           640       ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)           36928     ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 128)          73856     ['conv2d_1[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 128)          147584    ['conv2d_2[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)            295168    ['conv2d_3[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 256)            590080    ['conv2d_4[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 16, 16, 128)          295040    ['conv2d_5[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 16, 16, 256)          0         ['conv2d_transpose[0][0]',
#                                                                      'conv2d_3[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 128)          295040    ['concatenate[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 32, 32, 64)           73792     ['conv2d_6[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 32, 32, 128)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 64)           73792     ['concatenate_1[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 1)            577       ['conv2d_7[0][0]']
#
# ==================================================================================================
# Total params: 1882497 (7.18 MB)
# Trainable params: 1882497 (7.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training the Unet model

# %%
from keras.optimizers import Adam
opt = Adam(learning_rate=0.0001)
unet.compile(optimizer=opt, loss=losses.MeanSquaredError())
start = time.time()
model = unet.fit(train_input, train_output,
                epochs=100,
                shuffle=True,
                validation_data=(test_input, test_output),batch_size=16)
end = time.time()

print("The time of execution of above program is :",
      (end-start), "seconds")

unet.save(file_path + 'Model/unet_' + str(model_number) + '_L')

loss = model.history['loss']
loss = pd.DataFrame(loss)
loss.to_csv(file_path + 'Model/loss_'+ str(model_number) + '_L.csv')
val_loss = model.history['val_loss']
val_loss = pd.DataFrame(val_loss)
val_loss.to_csv(file_path  +'Model/val_loss_'+ str(model_number)+ '_L.csv')
# Out:
# Epoch 1/100
# 1757/1757 [==============================] - 33s 13ms/step - loss: 0.0201 - val_loss: 0.0180
# Epoch 2/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0177 - val_loss: 0.0171
# Epoch 3/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0169 - val_loss: 0.0165
# Epoch 4/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0162 - val_loss: 0.0158
# Epoch 5/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0156 - val_loss: 0.0154
# Epoch 6/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0152 - val_loss: 0.0149
# Epoch 7/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0149 - val_loss: 0.0147
# Epoch 8/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0145 - val_loss: 0.0145
# Epoch 9/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0141 - val_loss: 0.0149
# Epoch 10/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0138 - val_loss: 0.0137
# Epoch 11/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0135 - val_loss: 0.0134
# Epoch 12/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0131 - val_loss: 0.0148
# Epoch 13/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0128 - val_loss: 0.0140
# Epoch 14/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0125 - val_loss: 0.0129
# Epoch 15/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0122 - val_loss: 0.0133
# Epoch 16/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0119 - val_loss: 0.0127
# Epoch 17/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0115 - val_loss: 0.0125
# Epoch 18/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0111 - val_loss: 0.0122
# Epoch 19/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0109 - val_loss: 0.0121
# Epoch 20/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0104 - val_loss: 0.0122
# Epoch 21/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0101 - val_loss: 0.0120
# Epoch 22/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0098 - val_loss: 0.0119
# Epoch 23/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0095 - val_loss: 0.0122
# Epoch 24/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0091 - val_loss: 0.0121
# Epoch 25/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0088 - val_loss: 0.0123
# Epoch 26/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0084 - val_loss: 0.0123
# Epoch 27/100
# 1757/1757 [==============================] - 24s 13ms/step - loss: 0.0081 - val_loss: 0.0123
# Epoch 28/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0079 - val_loss: 0.0121
# Epoch 29/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0075 - val_loss: 0.0124
# Epoch 30/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0073 - val_loss: 0.0126
# Epoch 31/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0070 - val_loss: 0.0123
# Epoch 32/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0067 - val_loss: 0.0126
# Epoch 33/100
# 1757/1757 [==============================] - 26s 15ms/step - loss: 0.0065 - val_loss: 0.0123
# Epoch 34/100
# 1757/1757 [==============================] - 26s 15ms/step - loss: 0.0063 - val_loss: 0.0123
# Epoch 35/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0061 - val_loss: 0.0128
# Epoch 36/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0059 - val_loss: 0.0123
# Epoch 37/100
# 1757/1757 [==============================] - 27s 16ms/step - loss: 0.0057 - val_loss: 0.0128
# Epoch 38/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0056 - val_loss: 0.0123
# Epoch 39/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0054 - val_loss: 0.0125
# Epoch 40/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0053 - val_loss: 0.0128
# Epoch 41/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0051 - val_loss: 0.0126
# Epoch 42/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0049 - val_loss: 0.0127
# Epoch 43/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0048 - val_loss: 0.0131
# Epoch 44/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0047 - val_loss: 0.0129
# Epoch 45/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0046 - val_loss: 0.0131
# Epoch 46/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0045 - val_loss: 0.0130
# Epoch 47/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0043 - val_loss: 0.0129
# Epoch 48/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0042 - val_loss: 0.0130
# Epoch 49/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0041 - val_loss: 0.0131
# Epoch 50/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0040 - val_loss: 0.0130
# Epoch 51/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0039 - val_loss: 0.0132
# Epoch 52/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0039 - val_loss: 0.0132
# Epoch 53/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0038 - val_loss: 0.0131
# Epoch 54/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0037 - val_loss: 0.0131
# Epoch 55/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0036 - val_loss: 0.0131
# Epoch 56/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0036 - val_loss: 0.0132
# Epoch 57/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0035 - val_loss: 0.0133
# Epoch 58/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0035 - val_loss: 0.0132
# Epoch 59/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0034 - val_loss: 0.0135
# Epoch 60/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0034 - val_loss: 0.0135
# Epoch 61/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0033 - val_loss: 0.0133
# Epoch 62/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0033 - val_loss: 0.0135
# Epoch 63/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0032 - val_loss: 0.0134
# Epoch 64/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0032 - val_loss: 0.0133
# Epoch 65/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0031 - val_loss: 0.0134
# Epoch 66/100
# 1757/1757 [==============================] - 26s 15ms/step - loss: 0.0031 - val_loss: 0.0137
# Epoch 67/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0030 - val_loss: 0.0133
# Epoch 68/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0030 - val_loss: 0.0137
# Epoch 69/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0030 - val_loss: 0.0133
# Epoch 70/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0029 - val_loss: 0.0134
# Epoch 71/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0029 - val_loss: 0.0136
# Epoch 72/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0028 - val_loss: 0.0135
# Epoch 73/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0028 - val_loss: 0.0135
# Epoch 74/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0028 - val_loss: 0.0136
# Epoch 75/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0028 - val_loss: 0.0135
# Epoch 76/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0027 - val_loss: 0.0137
# Epoch 77/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0027 - val_loss: 0.0137
# Epoch 78/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0027 - val_loss: 0.0138
# Epoch 79/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0026 - val_loss: 0.0137
# Epoch 80/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0026 - val_loss: 0.0136
# Epoch 81/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0026 - val_loss: 0.0138
# Epoch 82/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0026 - val_loss: 0.0137
# Epoch 83/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0025 - val_loss: 0.0138
# Epoch 84/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0025 - val_loss: 0.0139
# Epoch 85/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0025 - val_loss: 0.0138
# Epoch 86/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0025 - val_loss: 0.0138
# Epoch 87/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0025 - val_loss: 0.0139
# Epoch 88/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0024 - val_loss: 0.0138
# Epoch 89/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0024 - val_loss: 0.0136
# Epoch 90/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0024 - val_loss: 0.0138
# Epoch 91/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0024 - val_loss: 0.0140
# Epoch 92/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0024 - val_loss: 0.0141
# Epoch 93/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0023 - val_loss: 0.0138
# Epoch 94/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0023 - val_loss: 0.0137
# Epoch 95/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0023 - val_loss: 0.0138
# Epoch 96/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0023 - val_loss: 0.0138
# Epoch 97/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0023 - val_loss: 0.0138
# Epoch 98/100
# 1757/1757 [==============================] - 22s 13ms/step - loss: 0.0022 - val_loss: 0.0140
# Epoch 99/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0022 - val_loss: 0.0142
# Epoch 100/100
# 1757/1757 [==============================] - 23s 13ms/step - loss: 0.0022 - val_loss: 0.0138
# The time of execution of above program is : 2304.419944524765 seconds

# %% [markdown]
# ## Testing the model

# %%
from tensorflow import keras
from PIL import Image, ImageOps
import numpy as np
import PIL
PIL.Image.MAX_IMAGE_PIXELS = 236958876

n_size = 32

def rgb_lab_normalized(im):
    rgb_array = np.array(im) # Convert to numpy array
    rgb_array_normalized = rgb_array / 255.0 # Normalize RGB values from 0 to 1
    lab_array_normalized = color.rgb2lab(rgb_array_normalized) # Convert RGB to LAB colorspace
    lab_array_normalized[..., 0] = (lab_array_normalized[..., 0]) / 100.0 # Scale LAB values to range [0, 1]
    lab_array_normalized[..., 1] = (lab_array_normalized[..., 1] + 128) / 255.0
    lab_array_normalized[..., 2] = (lab_array_normalized[..., 2] + 128) / 255.0
    lab_image_normalized = Image.fromarray((lab_array_normalized * 255).astype(np.uint8), mode='LAB')# Convert LAB array back to image
    return lab_image_normalized

def L_AB_rgb_unnormalized(ab_image, final_L):
    final_L[..., 0] = final_L[..., 0]*100.0
    ab_image[..., 0] = (ab_image[..., 0] * 255.0) - 128
    ab_image[..., 1] = (ab_image[..., 1] * 255.0) - 128
    LAB_array = np.dstack((final_L, ab_image[:,:,0], ab_image[:,:,1]))
    rgb_array_unnormalized = color.lab2rgb(LAB_array)# Convert LAB to RGB colorspace
    rgb_array_unnormalized = (rgb_array_unnormalized * 255).astype(np.uint8)# Scale RGB values back to the range [0, 255]
    rgb_image_unnormalized = Image.fromarray(rgb_array_unnormalized, mode='RGB')# Convert RGB array back to image
    return rgb_image_unnormalized

def crop_(im):
    width, height, depth = im.shape
    data = []
    for j in range(0,int(height/n_size)):
        for i in range(0,int(width/n_size)):
            im1 = im.crop((0 + (n_size*i), 0 + (n_size*j), n_size + (n_size*i), n_size + (n_size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            data.append(im1)
    return data


#----------------READING THE TEST IMAGE--------------------#
filename = str("INPUT_[09] Preserve and Protect.png")
test = Image.open(file_path+ "Testing/" + filename).convert('RGB')
test = np.array(rgb_lab_normalized(test))
test_L = test[:,:,0:1]
test_ab = test[:,:,1:3]
w_dirty, h_dirty, depth = test.shape
#----------------------------------------------------------#


#----------------GETTING AB--------------------#
autoencoder = keras.models.load_model(file_path + 'Model/unet_'+str(n_size)+'_ab')

xx = int(w_dirty/n_size)
final=[]
for portion in range(0,xx):
    im1 = test_ab.crop((n_size*portion, 0, (n_size*portion) + n_size, h_dirty))
    w1, h1, d1 = im1.shape
    w = int(w1/n_size)
    h = int(h1/n_size)
    neverbeforeseen = np.array(crop_(im1))
    decoded_imgs = autoencoder.predict(neverbeforeseen)
    col = np.vstack((decoded_imgs[0],decoded_imgs[1]))
    for i in range(2,h):
        col = np.vstack((col,decoded_imgs[i]))
    y = col
    y = (y * 255).astype('uint8')
    if portion == 0:
        final = y
    if portion > 0:
        final = np.hstack((final,y))

#----------------GETTING L--------------------#
autoencoder = keras.models.load_model(file_path + 'Model/unet_'+str(n_size)+'_L')

final_L=[]
for portion in range(0,xx):
    im1 = test_L.crop((n_size*portion, 0, (n_size*portion) + n_size, h_dirty))
    w1, h1, d1 = im1.shape
    w = int(w1/n_size)
    h = int(h1/n_size)
    neverbeforeseen = np.array(crop_(im1))
    decoded_imgs = autoencoder.predict(neverbeforeseen)
    col = np.vstack((decoded_imgs[0],decoded_imgs[1]))
    for i in range(2,h):
        col = np.vstack((col,decoded_imgs[i]))
    y = col
    y = (y * 255).astype('uint8')
    if portion == 0:
        final_L = y
    if portion > 0:
        final_L = np.hstack((final_L,y))

#----------------TEST ON L from model and AB from model--------------------#
final_L_AB = L_AB_rgb_unnormalized(final, final_L)
final_L_AB = np.squeeze(final_L_AB)
reconstructed_L_AB = Image.fromarray(final_L_AB)
reconstructed_L_AB.save(file_path + "Testing/"+"CLEAN"+str(size)+"_L_AB_"+filename)
plt.figure(), plt.imshow(reconstructed_L_AB)
# Out:
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 11ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 11ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 11ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-28ee218cadd5> in <cell line: 82>()
#      80 #----------------TEST ON L from input and AB from model--------------------#
#      81 final.T
# ---> 82 final_L_AB = AB_rgb_unnormalized(final, test_L)
#      83 final_L_AB = np.squeeze(final_L_AB)
#      84 reconstructed_L_AB = Image.fromarray(final_L_AB)
#
# <ipython-input-60-28ee218cadd5> in AB_rgb_unnormalized(ab_image, test_L)
#      19 def AB_rgb_unnormalized(ab_image, test_L):
#      20     #ab_array = np.array(ab_image/255)# Convert LAB image to numpy array
# ---> 21     ab_array[..., 0] = (ab_array[..., 0] * 255.0) - 128
#      22     ab_array[..., 1] = (ab_array[..., 1] * 255.0) - 128
#      23     LAB_array = np.dstack((test_L, ab_array[:,:,0].T, ab_array[:,:,1].T))
#
# NameError: name 'ab_array' is not defined
